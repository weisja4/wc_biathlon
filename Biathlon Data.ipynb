# %%
# pip install biathlonresults

# %%
import pandas as pd
import datetime as dt
import time
import requests
import biathlonresults

# %%
ROOT_API = 'http://biathlonresults.com/modules/sportapi/api/'

# %%
def _request(method, params):
    try:
        return requests.get(ROOT_API + method, params=params).json()
    except requests.exceptions.RequestException as e:
        print("Something went wrong", e)

# %%
def cups(season_id):
    """
    List of Cups
    :param season_id: season identifier (1819 for season 2018/2019, get others in a similar way)
    :return: list of cups
    :rtype: list
    """
    return _request("Cups", {'SeasonId': season_id})

# %%
def cup_results(cup_id):
    """
    Cup results
    BT1819SWRLCP__SMTS - Men's WC Total 2018/2019
    BT1819SWRLCP__SWTS - Women's WC Total 2018/2019
    :param cup_id: cup identifier, get it by calling cups(season_id)
    :return: selected cup results
    :rtype: dict
    """
    return _request("CupResults", {'CupId': cup_id})

# %%
def athletes(family_name='', given_name=''):
    """
    Search athlete
    :param family_name:
    :param given_name:
    :return: found athletes
    :rtype: dict
    """
    return _request("Athletes", {"FamilyName": family_name, "GivenName": given_name})

# %%
def cisbios(ibu_id):
    """
    Get athlete by id
    :param ibu_id: ibu identifier of athlete
    :return: athlete info
    :rtype: dict
    """
    return _request("CISBios", {"IBUId": ibu_id})


def all_results(ibu_id):
    """
    All races results of the athlete
    :param ibu_id: ibu identifier of athlete
    :return: races results
    :rtype: dict
    """
    return _request('AllResults', {"IBUId": ibu_id})


def events(season_id, level=0):
    """
    Events of cup (schedule)
    :param season_id: season identifier (1819 for season 2018/2019, get others in a similar way)
    :param level: 0 - all, 1 - BMW IBU WC, 2 - IBU Cup, 3 - Jr. Cup
    :return: list of events
    :rtype: list
    """
    return _request("Events", {"SeasonId": season_id, "Level": level})


def competitions(event_id):
    """
    List of races in stage
    :param event_id: event identifier, get it by calling events(season_id, level=0)
    :return: list of races
    :rtype: list
    """
    return _request('Competitions', {'EventId': event_id})


def results(race_id):
    """
    Race results
    :param race_id: race identifier, get it by calling competitions(event_id)
    :return: list of races
    :rtype: dict
    """
    return _request('Results', {'RaceId': race_id})


def stats(statistic_id, stat_id, by_what, gender_id, season_id='', organizer_id='', ibu_id='', nat=''):
    """
    Statistics
    Not sure how to use it right, here's default query parameters:
    StatisticId=WCPOD_M&StatId=WCPOD&byWhat=ATH&SeasonId=&OrganizerId=&GenderId=M&IBUId=&Nat=
    :param statistic_id:
    :param stat_id:
    :param by_what:
    :param gender_id:
    :param season_id:
    :param organizer_id:
    :param ibu_id:
    :param nat:
    :return: statistics
    :rtype: dict
    """
    return _request('Stats', {
        'StatisticId': statistic_id,
        'StatId': stat_id,
        'byWhat': by_what,
        'SeasonId': season_id,
        'OrganizerId': organizer_id,
        'GenderId': gender_id,
        'IBUId': ibu_id,
        'Nat': nat,
    })

# %%
import biathlonresults
athletes = biathlonresults.athletes('boe')
for i in athletes['Athletes']:
    print(i['IBUId'], i['FamilyName'], i['GivenName'])
# Out:
# BTNOR11605199301 BOE Johannes Thingnes
# BTNOR12307197201 BOE Karl Gunnar
# BTNOR12107199801 BOE Magnus
# BTNOR12907198801 BOE Tarjei
# BTSUI12006198401 BOECKLI Claudio
# BTNOR22702199401 BOEDAL Heidi Flo
# BTNOR11105199501 BOEDAL Isak Flo
# BTGER11606198601 BOEHM Daniel
# BTNED12007198101 BOEKEL Roel
# BTGER21108199601 BOEMMEL Anna

# %%
res = biathlonresults.all_results('BTNOR11605199301')
for i in res['Results'][:3]:
    print(i['Comp'], i['Season'], i['Place'], i['Rank'])
# Out:
# PU 19/20 Kontiolahti 4.
# SP 19/20 Kontiolahti 1.
# MS 19/20 Nove Mesto 1.

# %%
year = events(1819,1)
season = year[1]
# len(events(1819,1))
season
# Out:
# {'SeasonId': '1819',
#  'Trimester': '1',
#  'EventId': 'BT1819SWRLCP02',
#  'StartDate': '2018-12-10T12:00:00Z',
#  'EndDate': '2018-12-16T12:00:00Z',
#  'Description': 'BMW IBU World Cup Biathlon',
#  'ShortDescription': 'Hochfilzen',
#  'OrganizerId': 'HOC',
#  'Organizer': 'Hochfilzen',
#  'Nat': 'AUT',
#  'NatLong': 'Austria',
#  'MedalSetId': None,
#  'EventClassificationId': 'BTSWRLCP',
#  'Level': 1,
#  'UTCOffset': 1,
#  'IsActual': False,
#  'IsCurrent': False}

# %%
s_level = season['SeasonId'], season['Trimester'], season['ShortDescription'], season['StartDate'], season['EndDate']
s_level
# Out:
# ('1819', '1', 'Hochfilzen', '2018-12-10T12:00:00Z', '2018-12-16T12:00:00Z')

# %%
competitions('BT1819SWRLCP02')
# Out:
# [{'RaceId': 'BT1819SWRLCP02SWSP',
#   'km': '7.5',
#   'catId': 'SW',
#   'DisciplineId': 'SP',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-13T13:15:00Z',
#   'Description': 'Women 7.5 km Sprint Competition',
#   'ShortDescription': 'Women 7.5 km Sprint',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'I',
#   'NrShootings': 2,
#   'NrSpareRounds': 0,
#   'HasSpareRounds': False,
#   'PenaltySeconds': 0,
#   'NrLegs': 0,
#   'ShootingPositions': 'PS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHW7.5KMSP-----------FNL-000100--',
#   'GenderOrder': None},
#  {'RaceId': 'BT1819SWRLCP02SMSP',
#   'km': '10',
#   'catId': 'SM',
#   'DisciplineId': 'SP',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-14T13:15:00Z',
#   'Description': 'Men 10 km Sprint Competition',
#   'ShortDescription': 'Men 10 km Sprint',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'I',
#   'NrShootings': 2,
#   'NrSpareRounds': 0,
#   'HasSpareRounds': False,
#   'PenaltySeconds': 0,
#   'NrLegs': 0,
#   'ShootingPositions': 'PS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHM10KMSP------------FNL-000100--',
#   'GenderOrder': None},
#  {'RaceId': 'BT1819SWRLCP02SWPU',
#   'km': '10',
#   'catId': 'SW',
#   'DisciplineId': 'PU',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-15T10:30:00Z',
#   'Description': 'Women 10 km Pursuit Competition',
#   'ShortDescription': 'Women 10 km Pursuit',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'P',
#   'NrShootings': 4,
#   'NrSpareRounds': 0,
#   'HasSpareRounds': False,
#   'PenaltySeconds': 0,
#   'NrLegs': 0,
#   'ShootingPositions': 'PPSS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHW10KMPU------------FNL-000100--',
#   'GenderOrder': None},
#  {'RaceId': 'BT1819SWRLCP02SMPU',
#   'km': '12.5',
#   'catId': 'SM',
#   'DisciplineId': 'PU',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-15T13:45:00Z',
#   'Description': 'Men 12.5 km Pursuit Competition',
#   'ShortDescription': 'Men 12.5 km Pursuit',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'P',
#   'NrShootings': 4,
#   'NrSpareRounds': 0,
#   'HasSpareRounds': False,
#   'PenaltySeconds': 0,
#   'NrLegs': 0,
#   'ShootingPositions': 'PPSS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHM12.5KMPU----------FNL-000100--',
#   'GenderOrder': None},
#  {'RaceId': 'BT1819SWRLCP02SWRL',
#   'km': '4x6',
#   'catId': 'SW',
#   'DisciplineId': 'RL',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-16T10:15:00Z',
#   'Description': 'Women 4x6 km Relay Competition',
#   'ShortDescription': 'Women 4x6 km Relay',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'M',
#   'NrShootings': 2,
#   'NrSpareRounds': 3,
#   'HasSpareRounds': True,
#   'PenaltySeconds': 0,
#   'NrLegs': 4,
#   'ShootingPositions': 'PS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHW4X6KM-------------FNL-000100--',
#   'GenderOrder': None},
#  {'RaceId': 'BT1819SWRLCP02SMRL',
#   'km': '4x7.5',
#   'catId': 'SM',
#   'DisciplineId': 'RL',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-16T13:00:00Z',
#   'Description': 'Men 4x7.5 km Relay Competition',
#   'ShortDescription': 'Men 4x7.5 km Relay',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'M',
#   'NrShootings': 2,
#   'NrSpareRounds': 3,
#   'HasSpareRounds': True,
#   'PenaltySeconds': 0,
#   'NrLegs': 4,
#   'ShootingPositions': 'PS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHM4X7.5KM-----------FNL-000100--',
#   'GenderOrder': None}]

# %%
base = results('BT1819SWRLCP02SMSP')
comp = base['Competition']
comp
# Out:
# {'RaceId': 'BT1819SWRLCP02SMSP',
#  'km': '10',
#  'catId': 'SM',
#  'DisciplineId': 'SP',
#  'StatusId': 11,
#  'StatusText': 'Final',
#  'HasLiveData': False,
#  'IsLive': False,
#  'StartTime': '2018-12-14T13:15:00Z',
#  'Description': 'Men 10 km Sprint Competition',
#  'ShortDescription': 'Men 10 km Sprint',
#  'Location': None,
#  'ResultsCredit': None,
#  'TimingCredit': None,
#  'HasAnalysis': True,
#  'StartMode': None,
#  'NrShootings': 0,
#  'NrSpareRounds': 0,
#  'HasSpareRounds': False,
#  'PenaltySeconds': 0,
#  'NrLegs': 0,
#  'ShootingPositions': None,
#  'LocalUTCOffset': 1,
#  'RSC': None,
#  'GenderOrder': None}

# %%
comps = comp['DisciplineId'], comp['km'], comp['ShortDescription']
comps
# Out:
# ('SP', '10', 'Men 10 km Sprint')

# %%
base
# Out:
# {'RaceId': 'BT1819SWRLCP02SMSP',
#  'IsStartList': False,
#  'IsResult': True,
#  'Competition': {'RaceId': 'BT1819SWRLCP02SMSP',
#   'km': '10',
#   'catId': 'SM',
#   'DisciplineId': 'SP',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-14T13:15:00Z',
#   'Description': 'Men 10 km Sprint Competition',
#   'ShortDescription': 'Men 10 km Sprint',
#   'Location': None,
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': None,
#   'NrShootings': 0,
#   'NrSpareRounds': 0,
#   'HasSpareRounds': False,
#   'PenaltySeconds': 0,
#   'NrLegs': 0,
#   'ShootingPositions': None,
#   'LocalUTCOffset': 1,
#   'RSC': None,
#   'GenderOrder': None},
#  'SportEvt': {'SeasonId': '1819',
#   'Trimester': None,
#   'EventId': 'BT1819SWRLCP02',
#   'StartDate': '2018-12-10T12:00:00Z',
#   'EndDate': '2018-12-16T12:00:00Z',
#   'Description': 'BMW IBU World Cup Biathlon',
#   'ShortDescription': 'Hochfilzen',
#   'OrganizerId': None,
#   'Organizer': 'Hochfilzen',
#   'Nat': 'AUT',
#   'NatLong': None,
#   'MedalSetId': None,
#   'EventClassificationId': 'BTSWRLCP',
#   'Level': 1,
#   'UTCOffset': 1,
#   'IsActual': False,
#   'IsCurrent': None},
#  'Results': [{'StartOrder': 21,
#    'ResultOrder': 1,
#    'IRM': None,
#    'IBUId': 'BTNOR11605199301',
#    'Name': 'BOE Johannes Thingnes',
#    'ShortName': 'BOE J.',
#    'Nat': 'NOR',
#    'Bib': '21',
#    'Leg': None,
#    'Rank': '1',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '24:49.2',
#    'WC': '60',
#    'NC': '160',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:25:30Z',
#    'StartInfo': '14:25:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': 'o',
#    'Behind': '0.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '24:49.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 44,
#    'ResultOrder': 2,
#    'IRM': None,
#    'IBUId': 'BTFRA11409198801',
#    'Name': 'FOURCADE Martin',
#    'ShortName': 'FOURCADE M.',
#    'Nat': 'FRA',
#    'Bib': '44',
#    'Leg': None,
#    'Rank': '2',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '24:57.8',
#    'WC': '54',
#    'NC': '154',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:37:00Z',
#    'StartInfo': '14:37:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+8.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+8.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 31,
#    'ResultOrder': 3,
#    'IRM': None,
#    'IBUId': 'BTGER12403199001',
#    'Name': 'DOLL Benedikt',
#    'ShortName': 'DOLL B.',
#    'Nat': 'GER',
#    'Bib': '31',
#    'Leg': None,
#    'Rank': '3',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '24:59.4',
#    'WC': '48',
#    'NC': '148',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:30:30Z',
#    'StartInfo': '14:30:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+10.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+10.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 5,
#    'ResultOrder': 4,
#    'IRM': None,
#    'IBUId': 'BTFRA10207199101',
#    'Name': 'GUIGONNAT Antonin',
#    'ShortName': 'GUIGONNAT A.',
#    'Nat': 'FRA',
#    'Bib': '5',
#    'Leg': None,
#    'Rank': '4',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '25:15.1',
#    'WC': '43',
#    'NC': '143',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:17:30Z',
#    'StartInfo': '14:17:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+25.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+25.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 32,
#    'ResultOrder': 5,
#    'IRM': None,
#    'IBUId': 'BTGER11803198701',
#    'Name': 'PEIFFER Arnd',
#    'ShortName': 'PEIFFER A.',
#    'Nat': 'GER',
#    'Bib': '32',
#    'Leg': None,
#    'Rank': '5',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '25:17.1',
#    'WC': '40',
#    'NC': '140',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:31:00Z',
#    'StartInfo': '14:31:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+27.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+27.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 1,
#    'ResultOrder': 6,
#    'IRM': None,
#    'IBUId': 'BTAUT10911198601',
#    'Name': 'EBERHARD Julian',
#    'ShortName': 'EBERHARD J.',
#    'Nat': 'AUT',
#    'Bib': '1',
#    'Leg': None,
#    'Rank': '6',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '25:19.2',
#    'WC': '38',
#    'NC': '138',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:15:30Z',
#    'StartInfo': '14:15:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+30.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+30.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 9,
#    'ResultOrder': 7,
#    'IRM': None,
#    'IBUId': 'BTFRA10312199101',
#    'Name': 'DESTHIEUX Simon',
#    'ShortName': 'DESTHIEUX S.',
#    'Nat': 'FRA',
#    'Bib': '9',
#    'Leg': None,
#    'Rank': '7',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '25:25.5',
#    'WC': '36',
#    'NC': '136',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:19:30Z',
#    'StartInfo': '14:19:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+36.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+36.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 34,
#    'ResultOrder': 8,
#    'IRM': None,
#    'IBUId': 'BTRUS13101199201',
#    'Name': 'LOGINOV Alexander',
#    'ShortName': 'LOGINOV A.',
#    'Nat': 'RUS',
#    'Bib': '34',
#    'Leg': None,
#    'Rank': '8',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '25:27.7',
#    'WC': '34',
#    'NC': '134',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:32:00Z',
#    'StartInfo': '14:32:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+38.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+38.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 24,
#    'ResultOrder': 9,
#    'IRM': None,
#    'IBUId': 'BTCRO10108198701',
#    'Name': 'FAK Jakov',
#    'ShortName': 'FAK J.',
#    'Nat': 'SLO',
#    'Bib': '24',
#    'Leg': None,
#    'Rank': '9',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '25:35.5',
#    'WC': '32',
#    'NC': '132',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:27:00Z',
#    'StartInfo': '14:27:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+46.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+46.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 88,
#    'ResultOrder': 10,
#    'IRM': None,
#    'IBUId': 'BTNOR11205199201',
#    'Name': 'CHRISTIANSEN Vetle Sjaastad',
#    'ShortName': 'CHRISTIANSEN V.',
#    'Nat': 'NOR',
#    'Bib': '88',
#    'Leg': None,
#    'Rank': '10',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '25:40.0',
#    'WC': '31',
#    'NC': '131',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:59:00Z',
#    'StartInfo': '14:59:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+50.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+50.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 13,
#    'ResultOrder': 11,
#    'IRM': None,
#    'IBUId': 'BTSUI10510198901',
#    'Name': 'WEGER Benjamin',
#    'ShortName': 'WEGER B.',
#    'Nat': 'SUI',
#    'Bib': '13',
#    'Leg': None,
#    'Rank': '11',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '25:43.1',
#    'WC': '30',
#    'NC': '130',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:21:30Z',
#    'StartInfo': '14:21:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+53.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+53.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 54,
#    'ResultOrder': 12,
#    'IRM': None,
#    'IBUId': 'BTITA13009198901',
#    'Name': 'HOFER Lukas',
#    'ShortName': 'HOFER L.',
#    'Nat': 'ITA',
#    'Bib': '54',
#    'Leg': None,
#    'Rank': '12',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '25:44.0',
#    'WC': '29',
#    'NC': '129',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:42:00Z',
#    'StartInfo': '14:42:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+54.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+54.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 53,
#    'ResultOrder': 13,
#    'IRM': None,
#    'IBUId': 'BTSWE12803199701',
#    'Name': 'SAMUELSSON Sebastian',
#    'ShortName': 'SAMUELSSON S.',
#    'Nat': 'SWE',
#    'Bib': '53',
#    'Leg': None,
#    'Rank': '13',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '25:47.3',
#    'WC': '28',
#    'NC': '128',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:41:30Z',
#    'StartInfo': '14:41:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+58.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+58.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 15,
#    'ResultOrder': 14,
#    'IRM': None,
#    'IBUId': 'BTAUT12302198301',
#    'Name': 'EDER Simon',
#    'ShortName': 'EDER S.',
#    'Nat': 'AUT',
#    'Bib': '15',
#    'Leg': None,
#    'Rank': '14',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '25:49.7',
#    'WC': '27',
#    'NC': '127',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:22:30Z',
#    'StartInfo': '14:22:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:00.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:00.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 38,
#    'ResultOrder': 15,
#    'IRM': None,
#    'IBUId': 'BTFRA11111199101',
#    'Name': 'CLAUDE Florent',
#    'ShortName': 'CLAUDE F.',
#    'Nat': 'BEL',
#    'Bib': '38',
#    'Leg': None,
#    'Rank': '15',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '25:50.5',
#    'WC': '26',
#    'NC': '126',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:34:00Z',
#    'StartInfo': '14:34:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:01.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:01.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 10,
#    'ResultOrder': 16,
#    'IRM': None,
#    'IBUId': 'BTAUT11303198801',
#    'Name': 'LANDERTINGER Dominik',
#    'ShortName': 'LANDERTINGER D.',
#    'Nat': 'AUT',
#    'Bib': '10',
#    'Leg': None,
#    'Rank': '16',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '25:51.2',
#    'WC': '25',
#    'NC': '125',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:20:00Z',
#    'StartInfo': '14:20:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:02.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:02.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 83,
#    'ResultOrder': 17,
#    'IRM': None,
#    'IBUId': 'BTGER11705198801',
#    'Name': 'LESSER Erik',
#    'ShortName': 'LESSER E.',
#    'Nat': 'GER',
#    'Bib': '83',
#    'Leg': None,
#    'Rank': '17',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '25:55.4',
#    'WC': '24',
#    'NC': '124',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:56:30Z',
#    'StartInfo': '14:56:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:06.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:06.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 36,
#    'ResultOrder': 18,
#    'IRM': None,
#    'IBUId': 'BTSUI12007199001',
#    'Name': 'WIESTNER Serafin',
#    'ShortName': 'WIESTNER S.',
#    'Nat': 'SUI',
#    'Bib': '36',
#    'Leg': None,
#    'Rank': '18',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '25:57.0',
#    'WC': '23',
#    'NC': '123',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:33:00Z',
#    'StartInfo': '14:33:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:07.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:07.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 64,
#    'ResultOrder': 19,
#    'IRM': None,
#    'IBUId': 'BTRUS13103199301',
#    'Name': 'ELISEEV Matvey',
#    'ShortName': 'ELISEEV M.',
#    'Nat': 'RUS',
#    'Bib': '64',
#    'Leg': None,
#    'Rank': '19',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '25:58.8',
#    'WC': '22',
#    'NC': '122',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:47:00Z',
#    'StartInfo': '14:47:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:09.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:09.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 42,
#    'ResultOrder': 20,
#    'IRM': None,
#    'IBUId': 'BTCZE12301199101',
#    'Name': 'KRCMAR Michal',
#    'ShortName': 'KRCMAR M.',
#    'Nat': 'CZE',
#    'Bib': '42',
#    'Leg': None,
#    'Rank': '20',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '25:59.5',
#    'WC': '21',
#    'NC': '121',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:36:00Z',
#    'StartInfo': '14:36:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:10.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:10.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 52,
#    'ResultOrder': 21,
#    'IRM': None,
#    'IBUId': 'BTSLO10901198601',
#    'Name': 'BAUER Klemen',
#    'ShortName': 'BAUER K.',
#    'Nat': 'SLO',
#    'Bib': '52',
#    'Leg': None,
#    'Rank': '21',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:00.6',
#    'WC': '20',
#    'NC': '120',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:41:00Z',
#    'StartInfo': '14:41:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:11.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:11.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 43,
#    'ResultOrder': 22,
#    'IRM': None,
#    'IBUId': 'BTBUL11606198701',
#    'Name': 'ANEV Krasimir',
#    'ShortName': 'ANEV K.',
#    'Nat': 'BUL',
#    'Bib': '43',
#    'Leg': None,
#    'Rank': '22',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '26:04.8',
#    'WC': '19',
#    'NC': '119',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:36:30Z',
#    'StartInfo': '14:36:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:15.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:15.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 18,
#    'ResultOrder': 23,
#    'IRM': None,
#    'IBUId': 'BTGER11911199101',
#    'Name': 'KUEHN Johannes',
#    'ShortName': 'KUEHN J.',
#    'Nat': 'GER',
#    'Bib': '18',
#    'Leg': None,
#    'Rank': '23',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '26:05.1',
#    'WC': '18',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:24:00Z',
#    'StartInfo': '14:24:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:15.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:15.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 41,
#    'ResultOrder': 24,
#    'IRM': None,
#    'IBUId': 'BTFRA11107199501',
#    'Name': 'JACQUELIN Emilien',
#    'ShortName': 'JACQUELIN E.',
#    'Nat': 'FRA',
#    'Bib': '41',
#    'Leg': None,
#    'Rank': '24',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '26:05.6',
#    'WC': '17',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:35:30Z',
#    'StartInfo': '14:35:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:16.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:16.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 23,
#    'ResultOrder': 25,
#    'IRM': None,
#    'IBUId': 'BTGER11411198801',
#    'Name': 'SCHEMPP Simon',
#    'ShortName': 'SCHEMPP S.',
#    'Nat': 'GER',
#    'Bib': '23',
#    'Leg': None,
#    'Rank': '25',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:07.9',
#    'WC': '16',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:26:30Z',
#    'StartInfo': '14:26:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:18.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:18.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 25,
#    'ResultOrder': 26,
#    'IRM': None,
#    'IBUId': 'BTUKR13004198701',
#    'Name': 'PRYMA Artem',
#    'ShortName': 'PRYMA A.',
#    'Nat': 'UKR',
#    'Bib': '25',
#    'Leg': None,
#    'Rank': '26',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:08.9',
#    'WC': '15',
#    'NC': '115',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:27:30Z',
#    'StartInfo': '14:27:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:19.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:19.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 28,
#    'ResultOrder': 27,
#    'IRM': None,
#    'IBUId': 'BTSVK12508198701',
#    'Name': 'OTCENAS Martin',
#    'ShortName': 'OTCENAS M.',
#    'Nat': 'SVK',
#    'Bib': '28',
#    'Leg': None,
#    'Rank': '27',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:09.8',
#    'WC': '14',
#    'NC': '114',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:29:00Z',
#    'StartInfo': '14:29:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:20.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:20.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 8,
#    'ResultOrder': 28,
#    'IRM': None,
#    'IBUId': 'BTNOR12907198801',
#    'Name': 'BOE Tarjei',
#    'ShortName': 'BOE T.',
#    'Nat': 'NOR',
#    'Bib': '8',
#    'Leg': None,
#    'Rank': '28',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '26:16.0',
#    'WC': '13',
#    'NC': '113',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:19:00Z',
#    'StartInfo': '14:19:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:26.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:26.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 47,
#    'ResultOrder': 29,
#    'IRM': None,
#    'IBUId': 'BTFRA11305199201',
#    'Name': 'FINELLO Jeremy',
#    'ShortName': 'FINELLO J.',
#    'Nat': 'SUI',
#    'Bib': '47',
#    'Leg': None,
#    'Rank': '29',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:16.5',
#    'WC': '12',
#    'NC': '112',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:38:30Z',
#    'StartInfo': '14:38:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:27.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:27.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 56,
#    'ResultOrder': 30,
#    'IRM': None,
#    'IBUId': 'BTRUS10302198801',
#    'Name': 'LAPSHIN Timofei',
#    'ShortName': 'LAPSHIN T.',
#    'Nat': 'KOR',
#    'Bib': '56',
#    'Leg': None,
#    'Rank': '30',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:17.0',
#    'WC': '11',
#    'NC': '111',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:43:00Z',
#    'StartInfo': '14:43:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:27.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:27.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 27,
#    'ResultOrder': 31,
#    'IRM': None,
#    'IBUId': 'BTUSA11705198901',
#    'Name': 'NORDGREN Leif',
#    'ShortName': 'NORDGREN L.',
#    'Nat': 'USA',
#    'Bib': '27',
#    'Leg': None,
#    'Rank': '31',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:17.3',
#    'WC': '10',
#    'NC': '110',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:28:30Z',
#    'StartInfo': '14:28:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:28.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:28.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 33,
#    'ResultOrder': 32,
#    'IRM': None,
#    'IBUId': 'BTUKR10511199101',
#    'Name': 'PIDRUCHNYI Dmytro',
#    'ShortName': 'PIDRUCHNYI D.',
#    'Nat': 'UKR',
#    'Bib': '33',
#    'Leg': None,
#    'Rank': '32',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:19.4',
#    'WC': '9',
#    'NC': '109',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:31:30Z',
#    'StartInfo': '14:31:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:30.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:30.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 94,
#    'ResultOrder': 33,
#    'IRM': None,
#    'IBUId': 'BTGER10811199401',
#    'Name': 'HORN Philipp',
#    'ShortName': 'HORN P.',
#    'Nat': 'GER',
#    'Bib': '94',
#    'Leg': None,
#    'Rank': '33',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:19.5',
#    'WC': '8',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T14:02:00Z',
#    'StartInfo': '15:02:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:30.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:30.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 39,
#    'ResultOrder': 34,
#    'IRM': None,
#    'IBUId': 'BTITA10611198901',
#    'Name': 'WINDISCH Dominik',
#    'ShortName': 'WINDISCH D.',
#    'Nat': 'ITA',
#    'Bib': '39',
#    'Leg': None,
#    'Rank': '34',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '26:20.3',
#    'WC': '7',
#    'NC': '107',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:34:30Z',
#    'StartInfo': '14:34:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:31.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:31.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 40,
#    'ResultOrder': 35,
#    'IRM': None,
#    'IBUId': 'BTAUT13112199601',
#    'Name': 'LEITNER Felix',
#    'ShortName': 'LEITNER F.',
#    'Nat': 'AUT',
#    'Bib': '40',
#    'Leg': None,
#    'Rank': '35',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:26.3',
#    'WC': '6',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:35:00Z',
#    'StartInfo': '14:35:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:37.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:37.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 20,
#    'ResultOrder': 36,
#    'IRM': None,
#    'IBUId': 'BTLAT12705198801',
#    'Name': 'RASTORGUJEVS Andrejs',
#    'ShortName': 'RASTORGUJEVS A.',
#    'Nat': 'LAT',
#    'Bib': '20',
#    'Leg': None,
#    'Rank': '36',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:26.6',
#    'WC': '5',
#    'NC': '105',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:25:00Z',
#    'StartInfo': '14:25:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:37.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:37.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 101,
#    'ResultOrder': 37,
#    'IRM': None,
#    'IBUId': 'BTBUL12703199201',
#    'Name': 'GERDZHIKOV Dimitar',
#    'ShortName': 'GERDZHIKOV D.',
#    'Nat': 'BUL',
#    'Bib': '101',
#    'Leg': None,
#    'Rank': '37',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:28.6',
#    'WC': '4',
#    'NC': '104',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:05:30Z',
#    'StartInfo': '15:05:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:39.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:39.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 12,
#    'ResultOrder': 38,
#    'IRM': None,
#    'IBUId': 'BTNOR12303198601',
#    'Name': "L'ABEE-LUND Henrik",
#    'ShortName': "L'ABEE-LUND H.",
#    'Nat': 'NOR',
#    'Bib': '12',
#    'Leg': None,
#    'Rank': '38',
#    'Shootings': '2+1',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '26:28.7',
#    'WC': '3',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:21:00Z',
#    'StartInfo': '14:21:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:39.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:39.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 2,
#    'ResultOrder': 39,
#    'IRM': None,
#    'IBUId': 'BTFRA11608199201',
#    'Name': 'FILLON MAILLET Quentin',
#    'ShortName': 'FILLON MAILLET Q.',
#    'Nat': 'FRA',
#    'Bib': '2',
#    'Leg': None,
#    'Rank': '39',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '26:30.9',
#    'WC': '2',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:16:00Z',
#    'StartInfo': '14:16:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:41.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:41.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 68,
#    'ResultOrder': 40,
#    'IRM': None,
#    'IBUId': 'BTFRA11608199401',
#    'Name': 'BEGUE Aristide',
#    'ShortName': 'BEGUE A.',
#    'Nat': 'FRA',
#    'Bib': '68',
#    'Leg': None,
#    'Rank': '40',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '26:32.4',
#    'WC': '1',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:49:00Z',
#    'StartInfo': '14:49:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:43.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:43.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 57,
#    'ResultOrder': 41,
#    'IRM': None,
#    'IBUId': 'BTFIN11909199101',
#    'Name': 'GRONMAN Tuomas',
#    'ShortName': 'GRONMAN T.',
#    'Nat': 'FIN',
#    'Bib': '57',
#    'Leg': None,
#    'Rank': '41',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '26:37.2',
#    'WC': '',
#    'NC': '100',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:43:30Z',
#    'StartInfo': '14:43:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:48.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:48.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 46,
#    'ResultOrder': 42,
#    'IRM': None,
#    'IBUId': 'BTFIN12501199601',
#    'Name': 'SEPPALA Tero',
#    'ShortName': 'SEPPALA T.',
#    'Nat': 'FIN',
#    'Bib': '46',
#    'Leg': None,
#    'Rank': '42',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:38.0',
#    'WC': '',
#    'NC': '99',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:38:00Z',
#    'StartInfo': '14:38:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:48.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:48.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 90,
#    'ResultOrder': 43,
#    'IRM': None,
#    'IBUId': 'BTSUI12510198601',
#    'Name': 'TAMBORNINO Eligius',
#    'ShortName': 'TAMBORNINO E.',
#    'Nat': 'SUI',
#    'Bib': '90',
#    'Leg': None,
#    'Rank': '43',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '26:38.9',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T14:00:00Z',
#    'StartInfo': '15:00:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:49.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:49.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 70,
#    'ResultOrder': 44,
#    'IRM': None,
#    'IBUId': 'BTPOL10104198801',
#    'Name': 'SZCZUREK Lukasz',
#    'ShortName': 'SZCZUREK L.',
#    'Nat': 'POL',
#    'Bib': '70',
#    'Leg': None,
#    'Rank': '44',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:40.9',
#    'WC': '',
#    'NC': '97',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:50:00Z',
#    'StartInfo': '14:50:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:51.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:51.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 51,
#    'ResultOrder': 45,
#    'IRM': None,
#    'IBUId': 'BTBLR11005199301',
#    'Name': 'YALIOTNAU Raman',
#    'ShortName': 'YALIOTNAU R.',
#    'Nat': 'BLR',
#    'Bib': '51',
#    'Leg': None,
#    'Rank': '45',
#    'Shootings': '0+3',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '26:42.4',
#    'WC': '',
#    'NC': '96',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:40:30Z',
#    'StartInfo': '14:40:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:53.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:53.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 59,
#    'ResultOrder': 46,
#    'IRM': None,
#    'IBUId': 'BTCZE10302198301',
#    'Name': 'SLESINGR Michal',
#    'ShortName': 'SLESINGR M.',
#    'Nat': 'CZE',
#    'Bib': '59',
#    'Leg': None,
#    'Rank': '46',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:42.7',
#    'WC': '',
#    'NC': '95',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:44:30Z',
#    'StartInfo': '14:44:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:53.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:53.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 17,
#    'ResultOrder': 47,
#    'IRM': None,
#    'IBUId': 'BTBUL11703198701',
#    'Name': 'ILIEV Vladimir',
#    'ShortName': 'ILIEV V.',
#    'Nat': 'BUL',
#    'Bib': '17',
#    'Leg': None,
#    'Rank': '47',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '26:43.2',
#    'WC': '',
#    'NC': '94',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:23:30Z',
#    'StartInfo': '14:23:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:54.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:54.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 16,
#    'ResultOrder': 48,
#    'IRM': None,
#    'IBUId': 'BTKAZ11401199701',
#    'Name': 'YEREMIN Roman',
#    'ShortName': 'YEREMIN R.',
#    'Nat': 'KAZ',
#    'Bib': '16',
#    'Leg': None,
#    'Rank': '48',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '26:43.7',
#    'WC': '',
#    'NC': '93',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:23:00Z',
#    'StartInfo': '14:23:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:54.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:54.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 6,
#    'ResultOrder': 49,
#    'IRM': None,
#    'IBUId': 'BTUSA10806199501',
#    'Name': 'DOHERTY Sean',
#    'ShortName': 'DOHERTY S.',
#    'Nat': 'USA',
#    'Bib': '6',
#    'Leg': None,
#    'Rank': '49',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '26:47.1',
#    'WC': '',
#    'NC': '92',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:18:00Z',
#    'StartInfo': '14:18:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:57.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:57.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 3,
#    'ResultOrder': 50,
#    'IRM': None,
#    'IBUId': 'BTRUS11302198801',
#    'Name': 'GARANICHEV Evgeniy',
#    'ShortName': 'GARANICHEV E.',
#    'Nat': 'RUS',
#    'Bib': '3',
#    'Leg': None,
#    'Rank': '50',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '26:48.6',
#    'WC': '',
#    'NC': '91',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:16:30Z',
#    'StartInfo': '14:16:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:59.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:59.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 14,
#    'ResultOrder': 51,
#    'IRM': None,
#    'IBUId': 'BTCAN10611199001',
#    'Name': 'GOW Scott',
#    'ShortName': 'GOW S.',
#    'Nat': 'CAN',
#    'Bib': '14',
#    'Leg': None,
#    'Rank': '51',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:49.4',
#    'WC': '',
#    'NC': '90',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:22:00Z',
#    'StartInfo': '14:22:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:00.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:00.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 104,
#    'ResultOrder': 52,
#    'IRM': None,
#    'IBUId': 'BTPOL11906199101',
#    'Name': 'NEDZA-KUBINIEC Andrzej',
#    'ShortName': 'NEDZA-KUBINIEC A.',
#    'Nat': 'POL',
#    'Bib': '104',
#    'Leg': None,
#    'Rank': '52',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '26:49.6',
#    'WC': '',
#    'NC': '89',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:07:00Z',
#    'StartInfo': '15:07:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:00.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:00.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 85,
#    'ResultOrder': 53,
#    'IRM': None,
#    'IBUId': 'BTGER10405198301',
#    'Name': 'ROESCH Michael',
#    'ShortName': 'ROESCH M.',
#    'Nat': 'BEL',
#    'Bib': '85',
#    'Leg': None,
#    'Rank': '53',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:50.7',
#    'WC': '',
#    'NC': '88',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:57:30Z',
#    'StartInfo': '14:57:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:01.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:01.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 30,
#    'ResultOrder': 54,
#    'IRM': None,
#    'IBUId': 'BTSWE10809199501',
#    'Name': 'PONSILUOMA Martin',
#    'ShortName': 'PONSILUOMA M.',
#    'Nat': 'SWE',
#    'Bib': '30',
#    'Leg': None,
#    'Rank': '54',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:51.8',
#    'WC': '',
#    'NC': '87',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:30:00Z',
#    'StartInfo': '14:30:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:02.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:02.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 110,
#    'ResultOrder': 55,
#    'IRM': None,
#    'IBUId': 'BTITA10712199201',
#    'Name': 'MONTELLO Giuseppe',
#    'ShortName': 'MONTELLO G.',
#    'Nat': 'ITA',
#    'Bib': '110',
#    'Leg': None,
#    'Rank': '55',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:52.5',
#    'WC': '',
#    'NC': '86',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:10:00Z',
#    'StartInfo': '15:10:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:03.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:03.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 74,
#    'ResultOrder': 56,
#    'IRM': None,
#    'IBUId': 'BTFIN10202199101',
#    'Name': 'HIIDENSALO Olli',
#    'ShortName': 'HIIDENSALO O.',
#    'Nat': 'FIN',
#    'Bib': '74',
#    'Leg': None,
#    'Rank': '56',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:53.0',
#    'WC': '',
#    'NC': '85',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:52:00Z',
#    'StartInfo': '14:52:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:03.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:03.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 35,
#    'ResultOrder': 57,
#    'IRM': None,
#    'IBUId': 'BTCZE10906198401',
#    'Name': 'MORAVEC Ondrej',
#    'ShortName': 'MORAVEC O.',
#    'Nat': 'CZE',
#    'Bib': '35',
#    'Leg': None,
#    'Rank': '57',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '26:53.4',
#    'WC': '',
#    'NC': '84',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:32:30Z',
#    'StartInfo': '14:32:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:04.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:04.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 76,
#    'ResultOrder': 58,
#    'IRM': None,
#    'IBUId': 'BTRUS11912198601',
#    'Name': 'SLEPOV Alexey',
#    'ShortName': 'SLEPOV A.',
#    'Nat': 'RUS',
#    'Bib': '76',
#    'Leg': None,
#    'Rank': '58',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '26:54.5',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:53:00Z',
#    'StartInfo': '14:53:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:05.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:05.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 37,
#    'ResultOrder': 59,
#    'IRM': None,
#    'IBUId': 'BTRUS11903198701',
#    'Name': 'MALYSHKO Dmitry',
#    'ShortName': 'MALYSHKO D.',
#    'Nat': 'RUS',
#    'Bib': '37',
#    'Leg': None,
#    'Rank': '59',
#    'Shootings': '2+1',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '26:56.2',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:33:30Z',
#    'StartInfo': '14:33:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:07.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:07.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 19,
#    'ResultOrder': 60,
#    'IRM': None,
#    'IBUId': 'BTSUI12206199001',
#    'Name': 'DOLDER Mario',
#    'ShortName': 'DOLDER M.',
#    'Nat': 'SUI',
#    'Bib': '19',
#    'Leg': None,
#    'Rank': '60',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '26:57.6',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:24:30Z',
#    'StartInfo': '14:24:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:08.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:08.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 100,
#    'ResultOrder': 61,
#    'IRM': None,
#    'IBUId': 'BTCZE12112199801',
#    'Name': 'STVRTECKY Jakub',
#    'ShortName': 'STVRTECKY J.',
#    'Nat': 'CZE',
#    'Bib': '100',
#    'Leg': None,
#    'Rank': '61',
#    'Shootings': '2+1',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '26:58.9',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T14:05:00Z',
#    'StartInfo': '15:05:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:09.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:09.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 92,
#    'ResultOrder': 62,
#    'IRM': None,
#    'IBUId': 'BTNOR11610198801',
#    'Name': 'STENERSEN Torstein',
#    'ShortName': 'STENERSEN T.',
#    'Nat': 'SWE',
#    'Bib': '92',
#    'Leg': None,
#    'Rank': '62',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '26:59.2',
#    'WC': '',
#    'NC': '79',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:01:00Z',
#    'StartInfo': '15:01:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:10.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:10.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 61,
#    'ResultOrder': 63,
#    'IRM': None,
#    'IBUId': 'BTNOR13007199001',
#    'Name': 'BJOENTEGAARD Erlend',
#    'ShortName': 'BJOENTEGAARD E.',
#    'Nat': 'NOR',
#    'Bib': '61',
#    'Leg': None,
#    'Rank': '63',
#    'Shootings': '1+3',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '26:59.6',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:45:30Z',
#    'StartInfo': '14:45:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:10.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:10.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 72,
#    'ResultOrder': 64,
#    'IRM': None,
#    'IBUId': 'BTSVK12308199001',
#    'Name': 'HASILLA Tomas',
#    'ShortName': 'HASILLA T.',
#    'Nat': 'SVK',
#    'Bib': '72',
#    'Leg': None,
#    'Rank': '64',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '27:00.7',
#    'WC': '',
#    'NC': '77',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:51:00Z',
#    'StartInfo': '14:51:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:11.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:11.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 103,
#    'ResultOrder': 65,
#    'IRM': None,
#    'IBUId': 'BTLTU12811199201',
#    'Name': 'STROLIA Vytautas',
#    'ShortName': 'STROLIA V.',
#    'Nat': 'LTU',
#    'Bib': '103',
#    'Leg': None,
#    'Rank': '65',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '27:09.4',
#    'WC': '',
#    'NC': '76',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:06:30Z',
#    'StartInfo': '15:06:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:20.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:20.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 65,
#    'ResultOrder': 66,
#    'IRM': None,
#    'IBUId': 'BTCAN10411198601',
#    'Name': 'GREEN Brendan',
#    'ShortName': 'GREEN B.',
#    'Nat': 'CAN',
#    'Bib': '65',
#    'Leg': None,
#    'Rank': '66',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '27:11.1',
#    'WC': '',
#    'NC': '75',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:47:30Z',
#    'StartInfo': '14:47:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:21.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:21.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 7,
#    'ResultOrder': 67,
#    'IRM': None,
#    'IBUId': 'BTLTU10806199101',
#    'Name': 'DOMBROVSKI Karol',
#    'ShortName': 'DOMBROVSKI K.',
#    'Nat': 'LTU',
#    'Bib': '7',
#    'Leg': None,
#    'Rank': '67',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '27:13.7',
#    'WC': '',
#    'NC': '74',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:18:30Z',
#    'StartInfo': '14:18:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:24.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:24.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 106,
#    'ResultOrder': 68,
#    'IRM': None,
#    'IBUId': 'BTCAN12512198501',
#    'Name': 'SMITH Nathan',
#    'ShortName': 'SMITH N.',
#    'Nat': 'CAN',
#    'Bib': '106',
#    'Leg': None,
#    'Rank': '68',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '27:16.3',
#    'WC': '',
#    'NC': '73',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:08:00Z',
#    'StartInfo': '15:08:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:27.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:27.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 77,
#    'ResultOrder': 69,
#    'IRM': None,
#    'IBUId': 'BTEST11404197801',
#    'Name': 'LESSING Roland',
#    'ShortName': 'LESSING R.',
#    'Nat': 'EST',
#    'Bib': '77',
#    'Leg': None,
#    'Rank': '69',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '27:19.4',
#    'WC': '',
#    'NC': '72',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:53:30Z',
#    'StartInfo': '14:53:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:30.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:30.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 67,
#    'ResultOrder': 70,
#    'IRM': None,
#    'IBUId': 'BTSVK11005198301',
#    'Name': 'KAZAR Matej',
#    'ShortName': 'KAZAR M.',
#    'Nat': 'SVK',
#    'Bib': '67',
#    'Leg': None,
#    'Rank': '70',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '27:19.9',
#    'WC': '',
#    'NC': '71',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:48:30Z',
#    'StartInfo': '14:48:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:30.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:30.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 109,
#    'ResultOrder': 71,
#    'IRM': None,
#    'IBUId': 'BTSVK11107199601',
#    'Name': 'BARTKO Simon',
#    'ShortName': 'BARTKO S.',
#    'Nat': 'SVK',
#    'Bib': '109',
#    'Leg': None,
#    'Rank': '71',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '27:22.5',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T14:09:30Z',
#    'StartInfo': '15:09:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:33.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:33.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 84,
#    'ResultOrder': 72,
#    'IRM': None,
#    'IBUId': 'BTPOL12008199101',
#    'Name': 'GUZIK Grzegorz',
#    'ShortName': 'GUZIK G.',
#    'Nat': 'POL',
#    'Bib': '84',
#    'Leg': None,
#    'Rank': '72',
#    'Shootings': '2+1',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '27:25.1',
#    'WC': '',
#    'NC': '69',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:57:00Z',
#    'StartInfo': '14:57:00',
#    'StartRow': 0,
#    'StartLane': 0,
# ...
#    'RunTime': None,
#    'TotalTime': '27:45.7',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:58:30Z',
#    'StartInfo': '14:58:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:56.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:56.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 45,
#    'ResultOrder': 87,
#    'IRM': None,
#    'IBUId': 'BTNOR10311199601',
#    'Name': 'PETTERSEN Sindre',
#    'ShortName': 'PETTERSEN S.',
#    'Nat': 'NOR',
#    'Bib': '45',
#    'Leg': None,
#    'Rank': '87',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '27:46.8',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:37:30Z',
#    'StartInfo': '14:37:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:57.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:57.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 78,
#    'ResultOrder': 88,
#    'IRM': None,
#    'IBUId': 'BTLTU10105199001',
#    'Name': 'KAUKENAS Tomas',
#    'ShortName': 'KAUKENAS T.',
#    'Nat': 'LTU',
#    'Bib': '78',
#    'Leg': None,
#    'Rank': '88',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '27:47.0',
#    'WC': '',
#    'NC': '45',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:54:00Z',
#    'StartInfo': '14:54:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:57.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:57.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 80,
#    'ResultOrder': 89,
#    'IRM': None,
#    'IBUId': 'BTJPN10512199101',
#    'Name': 'KOBONOKI Tsukasa',
#    'ShortName': 'KOBONOKI T.',
#    'Nat': 'JPN',
#    'Bib': '80',
#    'Leg': None,
#    'Rank': '89',
#    'Shootings': '1+3',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '27:48.7',
#    'WC': '',
#    'NC': '43',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:55:00Z',
#    'StartInfo': '14:55:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:59.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:59.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 4,
#    'ResultOrder': 90,
#    'IRM': None,
#    'IBUId': 'BTUKR12807198801',
#    'Name': 'SEMENOV Sergii',
#    'ShortName': 'SEMENOV S.',
#    'Nat': 'UKR',
#    'Bib': '4',
#    'Leg': None,
#    'Rank': '90',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '27:55.4',
#    'WC': '',
#    'NC': '41',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:17:00Z',
#    'StartInfo': '14:17:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:06.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:06.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 97,
#    'ResultOrder': 91,
#    'IRM': None,
#    'IBUId': 'BTBLR11612199601',
#    'Name': 'SMOLSKI Anton',
#    'ShortName': 'SMOLSKI A.',
#    'Nat': 'BLR',
#    'Bib': '97',
#    'Leg': None,
#    'Rank': '91',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '27:55.7',
#    'WC': '',
#    'NC': '39',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:03:30Z',
#    'StartInfo': '15:03:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:06.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:06.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 48,
#    'ResultOrder': 92,
#    'IRM': None,
#    'IBUId': 'BTITA12908199101',
#    'Name': 'BORMOLINI Thomas',
#    'ShortName': 'BORMOLINI T.',
#    'Nat': 'ITA',
#    'Bib': '48',
#    'Leg': None,
#    'Rank': '92',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '27:56.3',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:39:00Z',
#    'StartInfo': '14:39:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:07.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:07.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 108,
#    'ResultOrder': 93,
#    'IRM': None,
#    'IBUId': 'BTRUS12802198801',
#    'Name': 'BOCHARNIKOV Sergey',
#    'ShortName': 'BOCHARNIKOV S.',
#    'Nat': 'BLR',
#    'Bib': '108',
#    'Leg': None,
#    'Rank': '93',
#    'Shootings': '0+3',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '27:58.2',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T14:09:00Z',
#    'StartInfo': '15:09:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:09.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:09.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 82,
#    'ResultOrder': 94,
#    'IRM': None,
#    'IBUId': 'BTGRE12406199301',
#    'Name': 'ANGELIS Apostolos',
#    'ShortName': 'ANGELIS A.',
#    'Nat': 'GRE',
#    'Bib': '82',
#    'Leg': None,
#    'Rank': '94',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '28:00.8',
#    'WC': '',
#    'NC': '33',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:56:00Z',
#    'StartInfo': '14:56:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:11.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:11.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 29,
#    'ResultOrder': 95,
#    'IRM': None,
#    'IBUId': 'BTJPN11705198801',
#    'Name': 'TACHIZAKI Mikito',
#    'ShortName': 'TACHIZAKI M.',
#    'Nat': 'JPN',
#    'Bib': '29',
#    'Leg': None,
#    'Rank': '95',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '28:00.9',
#    'WC': '',
#    'NC': '31',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:29:30Z',
#    'StartInfo': '14:29:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:11.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:11.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 98,
#    'ResultOrder': 96,
#    'IRM': None,
#    'IBUId': 'BTEST12507198301',
#    'Name': 'KOIV Kauri',
#    'ShortName': 'KOIV K.',
#    'Nat': 'EST',
#    'Bib': '98',
#    'Leg': None,
#    'Rank': '96',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '28:09.3',
#    'WC': '',
#    'NC': '29',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:04:00Z',
#    'StartInfo': '15:04:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:20.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:20.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 99,
#    'ResultOrder': 97,
#    'IRM': None,
#    'IBUId': 'BTLAT12409199201',
#    'Name': 'LUSA Daumants',
#    'ShortName': 'LUSA D.',
#    'Nat': 'LAT',
#    'Bib': '99',
#    'Leg': None,
#    'Rank': '97',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '28:12.8',
#    'WC': '',
#    'NC': '27',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:04:30Z',
#    'StartInfo': '15:04:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:23.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:23.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 11,
#    'ResultOrder': 98,
#    'IRM': None,
#    'IBUId': 'BTITA10211199201',
#    'Name': 'CHENAL Thierry',
#    'ShortName': 'CHENAL T.',
#    'Nat': 'ITA',
#    'Bib': '11',
#    'Leg': None,
#    'Rank': '98',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '28:17.2',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:20:30Z',
#    'StartInfo': '14:20:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:28.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:28.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 63,
#    'ResultOrder': 99,
#    'IRM': None,
#    'IBUId': 'BTROU10405199301',
#    'Name': 'BUTA George',
#    'ShortName': 'BUTA G.',
#    'Nat': 'ROU',
#    'Bib': '63',
#    'Leg': None,
#    'Rank': '99',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '28:21.1',
#    'WC': '',
#    'NC': '23',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:46:30Z',
#    'StartInfo': '14:46:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:31.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:31.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 105,
#    'ResultOrder': 100,
#    'IRM': None,
#    'IBUId': 'BTUSA11109199601',
#    'Name': 'COOPER Travis',
#    'ShortName': 'COOPER T.',
#    'Nat': 'USA',
#    'Bib': '105',
#    'Leg': None,
#    'Rank': '100',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '28:29.5',
#    'WC': '',
#    'NC': '21',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:07:30Z',
#    'StartInfo': '15:07:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:40.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:40.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 79,
#    'ResultOrder': 101,
#    'IRM': None,
#    'IBUId': 'BTCHN12602199601',
#    'Name': 'YAN Xingyuan',
#    'ShortName': 'YAN X.',
#    'Nat': 'CHN',
#    'Bib': '79',
#    'Leg': None,
#    'Rank': '101',
#    'Shootings': '0+3',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '28:32.7',
#    'WC': '',
#    'NC': '19',
#    'NOC': None,
#    'StartTime': '2018-12-14T13:54:30Z',
#    'StartInfo': '14:54:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:43.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:43.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 58,
#    'ResultOrder': 102,
#    'IRM': None,
#    'IBUId': 'BTUKR11706198801',
#    'Name': 'KILCHYTSKYY Vitaliy',
#    'ShortName': 'KILCHYTSKYY V.',
#    'Nat': 'UKR',
#    'Bib': '58',
#    'Leg': None,
#    'Rank': '102',
#    'Shootings': '3+1',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '28:37.4',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:44:00Z',
#    'StartInfo': '14:44:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:48.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:48.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 95,
#    'ResultOrder': 103,
#    'IRM': None,
#    'IBUId': 'BTROU10508199101',
#    'Name': 'SERBAN Denis',
#    'ShortName': 'SERBAN D.',
#    'Nat': 'ROU',
#    'Bib': '95',
#    'Leg': None,
#    'Rank': '103',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '28:57.0',
#    'WC': '',
#    'NC': '15',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:02:30Z',
#    'StartInfo': '15:02:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+4:07.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+4:07.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 66,
#    'ResultOrder': 104,
#    'IRM': None,
#    'IBUId': 'BTUSA10606199201',
#    'Name': 'SCHOMMER Paul',
#    'ShortName': 'SCHOMMER P.',
#    'Nat': 'USA',
#    'Bib': '66',
#    'Leg': None,
#    'Rank': '104',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '29:15.9',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:48:00Z',
#    'StartInfo': '14:48:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+4:26.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+4:26.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 107,
#    'ResultOrder': 105,
#    'IRM': None,
#    'IBUId': 'BTKAZ12704199301',
#    'Name': 'KHAMITGATIN Timur',
#    'ShortName': 'KHAMITGATIN T.',
#    'Nat': 'KAZ',
#    'Bib': '107',
#    'Leg': None,
#    'Rank': '105',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '29:45.3',
#    'WC': '',
#    'NC': '11',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:08:30Z',
#    'StartInfo': '15:08:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+4:56.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+4:56.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 102,
#    'ResultOrder': 106,
#    'IRM': None,
#    'IBUId': 'BTKOR10302199501',
#    'Name': 'CHOI Dujin',
#    'ShortName': 'CHOI D.',
#    'Nat': 'KOR',
#    'Bib': '102',
#    'Leg': None,
#    'Rank': '106',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '30:20.2',
#    'WC': '',
#    'NC': '9',
#    'NOC': None,
#    'StartTime': '2018-12-14T14:06:00Z',
#    'StartInfo': '15:06:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+5:31.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+5:31.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 22,
#    'ResultOrder': 10001,
#    'IRM': 'DNS',
#    'IBUId': 'BTSWE10310199201',
#    'Name': 'NELIN Jesper',
#    'ShortName': 'NELIN J.',
#    'Nat': 'SWE',
#    'Bib': '22',
#    'Leg': None,
#    'Rank': None,
#    'Shootings': None,
#    'ShootingTotal': None,
#    'RunTime': None,
#    'TotalTime': None,
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:26:00Z',
#    'StartInfo': '14:26:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': None,
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': 'DNS',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 26,
#    'ResultOrder': 10002,
#    'IRM': 'DNS',
#    'IBUId': 'BTCAN12803199301',
#    'Name': 'GOW Christian',
#    'ShortName': 'GOW C.',
#    'Nat': 'CAN',
#    'Bib': '26',
#    'Leg': None,
#    'Rank': None,
#    'Shootings': None,
#    'ShootingTotal': None,
#    'RunTime': None,
#    'TotalTime': None,
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T13:28:00Z',
#    'StartInfo': '14:28:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': None,
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': 'DNS',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 91,
#    'ResultOrder': 10003,
#    'IRM': 'DNS',
#    'IBUId': 'BTSLO12808199201',
#    'Name': 'TRSAN Rok',
#    'ShortName': 'TRSAN R.',
#    'Nat': 'SLO',
#    'Bib': '91',
#    'Leg': None,
#    'Rank': None,
#    'Shootings': None,
#    'ShootingTotal': None,
#    'RunTime': None,
#    'TotalTime': None,
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T14:00:30Z',
#    'StartInfo': '15:00:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': None,
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': 'DNS',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 96,
#    'ResultOrder': 10004,
#    'IRM': 'DNS',
#    'IBUId': 'BTSLO12202199601',
#    'Name': 'DRINOVEC Mitja',
#    'ShortName': 'DRINOVEC M.',
#    'Nat': 'SLO',
#    'Bib': '96',
#    'Leg': None,
#    'Rank': None,
#    'Shootings': None,
#    'ShootingTotal': None,
#    'RunTime': None,
#    'TotalTime': None,
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '2018-12-14T14:03:00Z',
#    'StartInfo': '15:03:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': None,
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': 'DNS',
#    'LegRank': None,
#    'TeamRankAfterLeg': None}]}

# %%
sprint = results('BT1819SWRLCP02SMSP')['Results']

# %%
gen = results('BT1819SWRLCP02SMSP')

# %%
s_level
# Out:
# ('1819', '1', 'Hochfilzen', '2018-12-10T12:00:00Z', '2018-12-16T12:00:00Z')

# %%
test
# Out:
# ('FOURCADE M.', 2, '24:57.8', '+8.6', 44, '0', '0+0')

# %%
s_level+test
# Out:
# ('1819',
#  '1',
#  'Hochfilzen',
#  '2018-12-10T12:00:00Z',
#  '2018-12-16T12:00:00Z',
#  ('1819', '1', 'Hochfilzen', '2018-12-10T12:00:00Z', '2018-12-16T12:00:00Z'),
#  'FOURCADE M.',
#  2,
#  '24:57.8',
#  '+8.6',
#  44,
#  '0',
#  '0+0')

# %%
test = sprint[1]['ShortName'], sprint[1]['ResultOrder'],sprint[1]['TotalTime'], sprint[1]['Behind'], sprint[1]['StartOrder'], sprint[1]['ShootingTotal'], sprint[1]['Shootings'],

test1 = s_level + test
test2 = pd.DataFrame(test1)

# %%
test2.T
# Out:
#       0  1           2                     3                     4  \
# 0  1819  1  Hochfilzen  2018-12-10T12:00:00Z  2018-12-16T12:00:00Z
#
#              5  6        7     8   9 10   11
# 0  FOURCADE M.  2  24:57.8  +8.6  44  0  0+0

# %%
year  = 1819    # Year  - Example: the 2018/2019 season is 1819 
level = 1       # Level - 1 is World Cup

# %%
season = events(1819,1)
event = season[1]

comp = competitions(event['EventId'])
comp
# Out:
# [{'RaceId': 'BT1819SWRLCP02SWSP',
#   'km': '7.5',
#   'catId': 'SW',
#   'DisciplineId': 'SP',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-13T13:15:00Z',
#   'Description': 'Women 7.5 km Sprint Competition',
#   'ShortDescription': 'Women 7.5 km Sprint',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'I',
#   'NrShootings': 2,
#   'NrSpareRounds': 0,
#   'HasSpareRounds': False,
#   'PenaltySeconds': 0,
#   'NrLegs': 0,
#   'ShootingPositions': 'PS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHW7.5KMSP-----------FNL-000100--',
#   'GenderOrder': None},
#  {'RaceId': 'BT1819SWRLCP02SMSP',
#   'km': '10',
#   'catId': 'SM',
#   'DisciplineId': 'SP',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-14T13:15:00Z',
#   'Description': 'Men 10 km Sprint Competition',
#   'ShortDescription': 'Men 10 km Sprint',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'I',
#   'NrShootings': 2,
#   'NrSpareRounds': 0,
#   'HasSpareRounds': False,
#   'PenaltySeconds': 0,
#   'NrLegs': 0,
#   'ShootingPositions': 'PS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHM10KMSP------------FNL-000100--',
#   'GenderOrder': None},
#  {'RaceId': 'BT1819SWRLCP02SWPU',
#   'km': '10',
#   'catId': 'SW',
#   'DisciplineId': 'PU',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-15T10:30:00Z',
#   'Description': 'Women 10 km Pursuit Competition',
#   'ShortDescription': 'Women 10 km Pursuit',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'P',
#   'NrShootings': 4,
#   'NrSpareRounds': 0,
#   'HasSpareRounds': False,
#   'PenaltySeconds': 0,
#   'NrLegs': 0,
#   'ShootingPositions': 'PPSS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHW10KMPU------------FNL-000100--',
#   'GenderOrder': None},
#  {'RaceId': 'BT1819SWRLCP02SMPU',
#   'km': '12.5',
#   'catId': 'SM',
#   'DisciplineId': 'PU',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-15T13:45:00Z',
#   'Description': 'Men 12.5 km Pursuit Competition',
#   'ShortDescription': 'Men 12.5 km Pursuit',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'P',
#   'NrShootings': 4,
#   'NrSpareRounds': 0,
#   'HasSpareRounds': False,
#   'PenaltySeconds': 0,
#   'NrLegs': 0,
#   'ShootingPositions': 'PPSS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHM12.5KMPU----------FNL-000100--',
#   'GenderOrder': None},
#  {'RaceId': 'BT1819SWRLCP02SWRL',
#   'km': '4x6',
#   'catId': 'SW',
#   'DisciplineId': 'RL',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-16T10:15:00Z',
#   'Description': 'Women 4x6 km Relay Competition',
#   'ShortDescription': 'Women 4x6 km Relay',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'M',
#   'NrShootings': 2,
#   'NrSpareRounds': 3,
#   'HasSpareRounds': True,
#   'PenaltySeconds': 0,
#   'NrLegs': 4,
#   'ShootingPositions': 'PS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHW4X6KM-------------FNL-000100--',
#   'GenderOrder': None},
#  {'RaceId': 'BT1819SWRLCP02SMRL',
#   'km': '4x7.5',
#   'catId': 'SM',
#   'DisciplineId': 'RL',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-16T13:00:00Z',
#   'Description': 'Men 4x7.5 km Relay Competition',
#   'ShortDescription': 'Men 4x7.5 km Relay',
#   'Location': 'Biathlon Stadium Hochfilzen',
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': 'M',
#   'NrShootings': 2,
#   'NrSpareRounds': 3,
#   'HasSpareRounds': True,
#   'PenaltySeconds': 0,
#   'NrLegs': 4,
#   'ShootingPositions': 'PS',
#   'LocalUTCOffset': 1,
#   'RSC': 'BTHM4X7.5KM-----------FNL-000100--',
#   'GenderOrder': None}]

# %%
race = comp[0]
final = results(race['RaceId'])
final
# output = final[0]['ShortName'], final[0]['ResultOrder'],final[0]['TotalTime'], final[0]['Behind'], final[0]['StartOrder'], final[0]['ShootingTotal'], final[0]['Shootings']
# output
# Out:
# {'RaceId': 'BT1819SWRLCP02SWSP',
#  'IsStartList': False,
#  'IsResult': True,
#  'Competition': {'RaceId': 'BT1819SWRLCP02SWSP',
#   'km': '7.5',
#   'catId': 'SW',
#   'DisciplineId': 'SP',
#   'StatusId': 11,
#   'StatusText': 'Final',
#   'HasLiveData': False,
#   'IsLive': False,
#   'StartTime': '2018-12-13T13:15:00Z',
#   'Description': 'Women 7.5 km Sprint Competition',
#   'ShortDescription': 'Women 7.5 km Sprint',
#   'Location': None,
#   'ResultsCredit': None,
#   'TimingCredit': None,
#   'HasAnalysis': True,
#   'StartMode': None,
#   'NrShootings': 0,
#   'NrSpareRounds': 0,
#   'HasSpareRounds': False,
#   'PenaltySeconds': 0,
#   'NrLegs': 0,
#   'ShootingPositions': None,
#   'LocalUTCOffset': 1,
#   'RSC': None,
#   'GenderOrder': None},
#  'SportEvt': {'SeasonId': '1819',
#   'Trimester': None,
#   'EventId': 'BT1819SWRLCP02',
#   'StartDate': '2018-12-10T12:00:00Z',
#   'EndDate': '2018-12-16T12:00:00Z',
#   'Description': 'BMW IBU World Cup Biathlon',
#   'ShortDescription': 'Hochfilzen',
#   'OrganizerId': None,
#   'Organizer': 'Hochfilzen',
#   'Nat': 'AUT',
#   'NatLong': None,
#   'MedalSetId': None,
#   'EventClassificationId': 'BTSWRLCP',
#   'Level': 1,
#   'UTCOffset': 1,
#   'IsActual': False,
#   'IsCurrent': None},
#  'Results': [{'StartOrder': 56,
#    'ResultOrder': 1,
#    'IRM': None,
#    'IBUId': 'BTITA20304199001',
#    'Name': 'WIERER Dorothea',
#    'ShortName': 'WIERER D.',
#    'Nat': 'ITA',
#    'Bib': '56',
#    'Leg': None,
#    'Rank': '1',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '21:04.9',
#    'WC': '60',
#    'NC': '160',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:43:00Z',
#    'StartInfo': '14:43:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': 'y',
#    'Behind': '0.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '21:04.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 22,
#    'ResultOrder': 2,
#    'IRM': None,
#    'IBUId': 'BTFIN21101198301',
#    'Name': 'MAKARAINEN Kaisa',
#    'ShortName': 'MAKARAINEN K.',
#    'Nat': 'FIN',
#    'Bib': '22',
#    'Leg': None,
#    'Rank': '2',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '21:05.5',
#    'WC': '54',
#    'NC': '154',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:26:00Z',
#    'StartInfo': '14:26:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': 'r',
#    'Behind': '+0.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+0.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 61,
#    'ResultOrder': 3,
#    'IRM': None,
#    'IBUId': 'BTRUS22302198502',
#    'Name': 'YURLOVA-PERCHT Ekaterina',
#    'ShortName': 'YURLOVA-PERCHT E.',
#    'Nat': 'RUS',
#    'Bib': '61',
#    'Leg': None,
#    'Rank': '3',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '21:29.3',
#    'WC': '48',
#    'NC': '148',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:45:30Z',
#    'StartInfo': '14:45:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+24.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+24.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 69,
#    'ResultOrder': 4,
#    'IRM': None,
#    'IBUId': 'BTITA20402199501',
#    'Name': 'VITTOZZI Lisa',
#    'ShortName': 'VITTOZZI L.',
#    'Nat': 'ITA',
#    'Bib': '69',
#    'Leg': None,
#    'Rank': '4',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '21:30.2',
#    'WC': '43',
#    'NC': '143',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:49:30Z',
#    'StartInfo': '14:49:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+25.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+25.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 31,
#    'ResultOrder': 5,
#    'IRM': None,
#    'IBUId': 'BTPOL22708199101',
#    'Name': 'HOJNISZ-STAREGA Monika',
#    'ShortName': 'HOJNISZ-STAREGA M.',
#    'Nat': 'POL',
#    'Bib': '31',
#    'Leg': None,
#    'Rank': '5',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '21:33.1',
#    'WC': '40',
#    'NC': '140',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:30:30Z',
#    'StartInfo': '14:30:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+28.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+28.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 4,
#    'ResultOrder': 6,
#    'IRM': None,
#    'IBUId': 'BTBLR23007199101',
#    'Name': 'KRYUKO Iryna',
#    'ShortName': 'KRYUKO I.',
#    'Nat': 'BLR',
#    'Bib': '4',
#    'Leg': None,
#    'Rank': '6',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '21:43.4',
#    'WC': '38',
#    'NC': '138',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:17:00Z',
#    'StartInfo': '14:17:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+38.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+38.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 10,
#    'ResultOrder': 7,
#    'IRM': None,
#    'IBUId': 'BTSVK22510199201',
#    'Name': 'FIALKOVA Paulina',
#    'ShortName': 'FIALKOVA P.',
#    'Nat': 'SVK',
#    'Bib': '10',
#    'Leg': None,
#    'Rank': '7',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '21:48.7',
#    'WC': '36',
#    'NC': '136',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:20:00Z',
#    'StartInfo': '14:20:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+43.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+43.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 13,
#    'ResultOrder': 8,
#    'IRM': None,
#    'IBUId': 'BTFRA21202199301',
#    'Name': 'CHEVALIER Anais',
#    'ShortName': 'CHEVALIER A.',
#    'Nat': 'FRA',
#    'Bib': '13',
#    'Leg': None,
#    'Rank': '8',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '21:50.3',
#    'WC': '34',
#    'NC': '134',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:21:30Z',
#    'StartInfo': '14:21:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+45.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+45.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 20,
#    'ResultOrder': 9,
#    'IRM': None,
#    'IBUId': 'BTRUS22608198701',
#    'Name': 'STARYKH Irina',
#    'ShortName': 'STARYKH I.',
#    'Nat': 'RUS',
#    'Bib': '20',
#    'Leg': None,
#    'Rank': '9',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '21:52.4',
#    'WC': '32',
#    'NC': '132',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:25:00Z',
#    'StartInfo': '14:25:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+47.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+47.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 2,
#    'ResultOrder': 10,
#    'IRM': None,
#    'IBUId': 'BTRUS22808198401',
#    'Name': 'KUZMINA Anastasiya',
#    'ShortName': 'KUZMINA A.',
#    'Nat': 'SVK',
#    'Bib': '2',
#    'Leg': None,
#    'Rank': '10',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '21:54.5',
#    'WC': '31',
#    'NC': '131',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:16:00Z',
#    'StartInfo': '14:16:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+49.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+49.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 15,
#    'ResultOrder': 11,
#    'IRM': None,
#    'IBUId': 'BTGER22403199201',
#    'Name': 'HINZ Vanessa',
#    'ShortName': 'HINZ V.',
#    'Nat': 'GER',
#    'Bib': '15',
#    'Leg': None,
#    'Rank': '11',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '21:57.5',
#    'WC': '30',
#    'NC': '130',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:22:30Z',
#    'StartInfo': '14:22:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+52.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+52.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 75,
#    'ResultOrder': 12,
#    'IRM': None,
#    'IBUId': 'BTSWE22803199001',
#    'Name': 'BRORSSON Mona',
#    'ShortName': 'BRORSSON M.',
#    'Nat': 'SWE',
#    'Bib': '75',
#    'Leg': None,
#    'Rank': '12',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:01.7',
#    'WC': '29',
#    'NC': '129',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:52:30Z',
#    'StartInfo': '14:52:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+56.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+56.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 5,
#    'ResultOrder': 13,
#    'IRM': None,
#    'IBUId': 'BTGER22403198701',
#    'Name': 'HILDEBRAND Franziska',
#    'ShortName': 'HILDEBRAND F.',
#    'Nat': 'GER',
#    'Bib': '5',
#    'Leg': None,
#    'Rank': '13',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:04.2',
#    'WC': '28',
#    'NC': '128',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:17:30Z',
#    'StartInfo': '14:17:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+59.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+59.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 11,
#    'ResultOrder': 14,
#    'IRM': None,
#    'IBUId': 'BTRUS21101198401',
#    'Name': 'FROLINA Anna',
#    'ShortName': 'FROLINA A.',
#    'Nat': 'KOR',
#    'Bib': '11',
#    'Leg': None,
#    'Rank': '14',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:05.4',
#    'WC': '27',
#    'NC': '127',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:20:30Z',
#    'StartInfo': '14:20:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:00.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:00.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 52,
#    'ResultOrder': 15,
#    'IRM': None,
#    'IBUId': 'BTGER20905198901',
#    'Name': 'HORCHLER Karolin',
#    'ShortName': 'HORCHLER K.',
#    'Nat': 'GER',
#    'Bib': '52',
#    'Leg': None,
#    'Rank': '14',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '22:05.4',
#    'WC': '27',
#    'NC': '127',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:41:00Z',
#    'StartInfo': '14:41:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:00.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:00.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 50,
#    'ResultOrder': 16,
#    'IRM': None,
#    'IBUId': 'BTNOR22105199001',
#    'Name': 'ECKHOFF Tiril',
#    'ShortName': 'ECKHOFF T.',
#    'Nat': 'NOR',
#    'Bib': '50',
#    'Leg': None,
#    'Rank': '16',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:09.8',
#    'WC': '25',
#    'NC': '125',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:40:00Z',
#    'StartInfo': '14:40:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:04.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:04.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 42,
#    'ResultOrder': 17,
#    'IRM': None,
#    'IBUId': 'BTFRA20508199101',
#    'Name': 'AYMONIER Celia',
#    'ShortName': 'AYMONIER C.',
#    'Nat': 'FRA',
#    'Bib': '42',
#    'Leg': None,
#    'Rank': '17',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:12.4',
#    'WC': '24',
#    'NC': '124',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:36:00Z',
#    'StartInfo': '14:36:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:07.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:07.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 17,
#    'ResultOrder': 18,
#    'IRM': None,
#    'IBUId': 'BTRUS22905199701',
#    'Name': 'VASNETCOVA Valeriia',
#    'ShortName': 'VASNETCOVA V.',
#    'Nat': 'RUS',
#    'Bib': '17',
#    'Leg': None,
#    'Rank': '18',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '22:12.6',
#    'WC': '23',
#    'NC': '123',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:23:30Z',
#    'StartInfo': '14:23:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:07.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:07.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 74,
#    'ResultOrder': 19,
#    'IRM': None,
#    'IBUId': 'BTITA22410199001',
#    'Name': 'SANFILIPPO Federica',
#    'ShortName': 'SANFILIPPO F.',
#    'Nat': 'ITA',
#    'Bib': '74',
#    'Leg': None,
#    'Rank': '19',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:13.4',
#    'WC': '22',
#    'NC': '122',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:52:00Z',
#    'StartInfo': '14:52:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:08.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:08.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 38,
#    'ResultOrder': 20,
#    'IRM': None,
#    'IBUId': 'BTNOR22309199601',
#    'Name': 'TANDREVOLD Ingrid Landmark',
#    'ShortName': 'TANDREVOLD I.',
#    'Nat': 'NOR',
#    'Bib': '38',
#    'Leg': None,
#    'Rank': '20',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:13.5',
#    'WC': '21',
#    'NC': '121',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:34:00Z',
#    'StartInfo': '14:34:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:08.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:08.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 45,
#    'ResultOrder': 21,
#    'IRM': None,
#    'IBUId': 'BTSUI20902199401',
#    'Name': 'GASPARIN Aita',
#    'ShortName': 'GASPARIN A.',
#    'Nat': 'SUI',
#    'Bib': '45',
#    'Leg': None,
#    'Rank': '21',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '22:15.4',
#    'WC': '20',
#    'NC': '120',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:37:30Z',
#    'StartInfo': '14:37:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:10.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:10.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 28,
#    'ResultOrder': 22,
#    'IRM': None,
#    'IBUId': 'BTAUT21612199301',
#    'Name': 'HAUSER Lisa Theresa',
#    'ShortName': 'HAUSER L.',
#    'Nat': 'AUT',
#    'Bib': '28',
#    'Leg': None,
#    'Rank': '22',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:16.8',
#    'WC': '19',
#    'NC': '119',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:29:00Z',
#    'StartInfo': '14:29:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:11.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:11.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 30,
#    'ResultOrder': 23,
#    'IRM': None,
#    'IBUId': 'BTFRA20910199601',
#    'Name': 'SIMON Julia',
#    'ShortName': 'SIMON J.',
#    'Nat': 'FRA',
#    'Bib': '30',
#    'Leg': None,
#    'Rank': '23',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:17.9',
#    'WC': '18',
#    'NC': '118',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:30:00Z',
#    'StartInfo': '14:30:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:13.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:13.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 12,
#    'ResultOrder': 24,
#    'IRM': None,
#    'IBUId': 'BTSUI20212199101',
#    'Name': 'GASPARIN Elisa',
#    'ShortName': 'GASPARIN E.',
#    'Nat': 'SUI',
#    'Bib': '12',
#    'Leg': None,
#    'Rank': '24',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:18.7',
#    'WC': '17',
#    'NC': '117',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:21:00Z',
#    'StartInfo': '14:21:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:13.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:13.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 6,
#    'ResultOrder': 25,
#    'IRM': None,
#    'IBUId': 'BTCZE20912198801',
#    'Name': 'VITKOVA Veronika',
#    'ShortName': 'VITKOVA V.',
#    'Nat': 'CZE',
#    'Bib': '6',
#    'Leg': None,
#    'Rank': '25',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:19.7',
#    'WC': '16',
#    'NC': '116',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:18:00Z',
#    'StartInfo': '14:18:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:14.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:14.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 68,
#    'ResultOrder': 26,
#    'IRM': None,
#    'IBUId': 'BTJPN22505199001',
#    'Name': 'MAEDA Sari',
#    'ShortName': 'MAEDA S.',
#    'Nat': 'JPN',
#    'Bib': '68',
#    'Leg': None,
#    'Rank': '26',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:23.8',
#    'WC': '15',
#    'NC': '115',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:49:00Z',
#    'StartInfo': '14:49:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:18.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:18.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 93,
#    'ResultOrder': 27,
#    'IRM': None,
#    'IBUId': 'BTUKR20901198701',
#    'Name': 'PIDHRUSHNA Olena',
#    'ShortName': 'PIDHRUSHNA O.',
#    'Nat': 'UKR',
#    'Bib': '93',
#    'Leg': None,
#    'Rank': '27',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:24.7',
#    'WC': '14',
#    'NC': '114',
#    'NOC': None,
#    'StartTime': '1900-01-01T14:01:30Z',
#    'StartInfo': '15:01:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:19.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:19.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 3,
#    'ResultOrder': 28,
#    'IRM': None,
#    'IBUId': 'BTGER21103199401',
#    'Name': 'PREUSS Franziska',
#    'ShortName': 'PREUSS F.',
#    'Nat': 'GER',
#    'Bib': '3',
#    'Leg': None,
#    'Rank': '28',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:25.4',
#    'WC': '13',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:16:30Z',
#    'StartInfo': '14:16:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:20.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:20.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 1,
#    'ResultOrder': 29,
#    'IRM': None,
#    'IBUId': 'BTCZE20301199101',
#    'Name': 'KRISTEJN PUSKARCIKOVA Eva',
#    'ShortName': 'KRISTEJN PUSKARCIKOVA E.',
#    'Nat': 'CZE',
#    'Bib': '1',
#    'Leg': None,
#    'Rank': '29',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:25.9',
#    'WC': '12',
#    'NC': '112',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:15:30Z',
#    'StartInfo': '14:15:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:21.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:21.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 16,
#    'ResultOrder': 30,
#    'IRM': None,
#    'IBUId': 'BTSWE22706199401',
#    'Name': 'PERSSON Linn',
#    'ShortName': 'PERSSON L.',
#    'Nat': 'SWE',
#    'Bib': '16',
#    'Leg': None,
#    'Rank': '30',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:33.1',
#    'WC': '11',
#    'NC': '111',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:23:00Z',
#    'StartInfo': '14:23:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:28.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:28.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 29,
#    'ResultOrder': 31,
#    'IRM': None,
#    'IBUId': 'BTFRA21505198701',
#    'Name': 'BESCOND Anais',
#    'ShortName': 'BESCOND A.',
#    'Nat': 'FRA',
#    'Bib': '29',
#    'Leg': None,
#    'Rank': '31',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:33.4',
#    'WC': '10',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:29:30Z',
#    'StartInfo': '14:29:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:28.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:28.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 21,
#    'ResultOrder': 32,
#    'IRM': None,
#    'IBUId': 'BTRUS20907199301',
#    'Name': 'PAVLOVA Evgeniya',
#    'ShortName': 'PAVLOVA E.',
#    'Nat': 'RUS',
#    'Bib': '21',
#    'Leg': None,
#    'Rank': '32',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:33.9',
#    'WC': '9',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:25:30Z',
#    'StartInfo': '14:25:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:29.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:29.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 39,
#    'ResultOrder': 33,
#    'IRM': None,
#    'IBUId': 'BTSUI20107199501',
#    'Name': 'HAECKI Lena',
#    'ShortName': 'HAECKI L.',
#    'Nat': 'SUI',
#    'Bib': '39',
#    'Leg': None,
#    'Rank': '33',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '22:37.1',
#    'WC': '8',
#    'NC': '108',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:34:30Z',
#    'StartInfo': '14:34:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:32.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:32.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 23,
#    'ResultOrder': 34,
#    'IRM': None,
#    'IBUId': 'BTUSA22502198301',
#    'Name': 'DUNKLEE Susan',
#    'ShortName': 'DUNKLEE S.',
#    'Nat': 'USA',
#    'Bib': '23',
#    'Leg': None,
#    'Rank': '34',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:37.9',
#    'WC': '7',
#    'NC': '107',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:26:30Z',
#    'StartInfo': '14:26:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:33.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:33.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 19,
#    'ResultOrder': 35,
#    'IRM': None,
#    'IBUId': 'BTSWE20211199501',
#    'Name': 'OEBERG Hanna',
#    'ShortName': 'OEBERG H.',
#    'Nat': 'SWE',
#    'Bib': '19',
#    'Leg': None,
#    'Rank': '35',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:38.9',
#    'WC': '6',
#    'NC': '106',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:24:30Z',
#    'StartInfo': '14:24:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:34.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:34.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 36,
#    'ResultOrder': 36,
#    'IRM': None,
#    'IBUId': 'BTJPN21301198901',
#    'Name': 'TACHIZAKI Fuyuko',
#    'ShortName': 'TACHIZAKI F.',
#    'Nat': 'JPN',
#    'Bib': '36',
#    'Leg': None,
#    'Rank': '36',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:40.6',
#    'WC': '5',
#    'NC': '105',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:33:00Z',
#    'StartInfo': '14:33:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:35.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:35.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 58,
#    'ResultOrder': 37,
#    'IRM': None,
#    'IBUId': 'BTNOR20607199701',
#    'Name': 'KALKENBERG Emilie Aagheim',
#    'ShortName': 'KALKENBERG E.',
#    'Nat': 'NOR',
#    'Bib': '58',
#    'Leg': None,
#    'Rank': '37',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:42.0',
#    'WC': '4',
#    'NC': '104',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:44:00Z',
#    'StartInfo': '14:44:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:37.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:37.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 7,
#    'ResultOrder': 38,
#    'IRM': None,
#    'IBUId': 'BTAUT21701199101',
#    'Name': 'INNERHOFER Katharina',
#    'ShortName': 'INNERHOFER K.',
#    'Nat': 'AUT',
#    'Bib': '7',
#    'Leg': None,
#    'Rank': '38',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:42.8',
#    'WC': '3',
#    'NC': '103',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:18:30Z',
#    'StartInfo': '14:18:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:37.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:37.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 64,
#    'ResultOrder': 39,
#    'IRM': None,
#    'IBUId': 'BTSLO21005199701',
#    'Name': 'POJE Urska',
#    'ShortName': 'POJE U.',
#    'Nat': 'SLO',
#    'Bib': '64',
#    'Leg': None,
#    'Rank': '38',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '22:42.8',
#    'WC': '3',
#    'NC': '103',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:47:00Z',
#    'StartInfo': '14:47:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:37.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:37.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 44,
#    'ResultOrder': 40,
#    'IRM': None,
#    'IBUId': 'BTBLR20501199601',
#    'Name': 'ALIMBEKAVA Dzinara',
#    'ShortName': 'ALIMBEKAVA D.',
#    'Nat': 'BLR',
#    'Bib': '44',
#    'Leg': None,
#    'Rank': '40',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:47.3',
#    'WC': '1',
#    'NC': '101',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:37:00Z',
#    'StartInfo': '14:37:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:42.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:42.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 27,
#    'ResultOrder': 41,
#    'IRM': None,
#    'IBUId': 'BTFRA20407199601',
#    'Name': 'BRAISAZ Justine',
#    'ShortName': 'BRAISAZ J.',
#    'Nat': 'FRA',
#    'Bib': '27',
#    'Leg': None,
#    'Rank': '41',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '22:49.1',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:28:30Z',
#    'StartInfo': '14:28:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:44.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:44.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 26,
#    'ResultOrder': 42,
#    'IRM': None,
#    'IBUId': 'BTSWE21811199302',
#    'Name': 'NILSSON Emma',
#    'ShortName': 'NILSSON E.',
#    'Nat': 'SWE',
#    'Bib': '26',
#    'Leg': None,
#    'Rank': '42',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:51.4',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:28:00Z',
#    'StartInfo': '14:28:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:46.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:46.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 8,
#    'ResultOrder': 43,
#    'IRM': None,
#    'IBUId': 'BTITA22711199101',
#    'Name': 'RUNGGALDIER Alexia',
#    'ShortName': 'RUNGGALDIER A.',
#    'Nat': 'ITA',
#    'Bib': '8',
#    'Leg': None,
#    'Rank': '43',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '22:52.8',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:19:00Z',
#    'StartInfo': '14:19:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:47.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:47.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 46,
#    'ResultOrder': 44,
#    'IRM': None,
#    'IBUId': 'BTUSA22806199201',
#    'Name': 'REID Joanne',
#    'ShortName': 'REID J.',
#    'Nat': 'USA',
#    'Bib': '46',
#    'Leg': None,
#    'Rank': '44',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '22:53.2',
#    'WC': '',
#    'NC': '97',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:38:00Z',
#    'StartInfo': '14:38:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:48.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:48.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 94,
#    'ResultOrder': 45,
#    'IRM': None,
#    'IBUId': 'BTCHN21005199201',
#    'Name': 'ZHANG Yan',
#    'ShortName': 'ZHANG Y.',
#    'Nat': 'CHN',
#    'Bib': '94',
#    'Leg': None,
#    'Rank': '45',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '22:54.7',
#    'WC': '',
#    'NC': '96',
#    'NOC': None,
#    'StartTime': '1900-01-01T14:02:00Z',
#    'StartInfo': '15:02:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:49.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:49.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 33,
#    'ResultOrder': 46,
#    'IRM': None,
#    'IBUId': 'BTGER22505199601',
#    'Name': 'WEIDEL Anna',
#    'ShortName': 'WEIDEL A.',
#    'Nat': 'GER',
#    'Bib': '33',
#    'Leg': None,
#    'Rank': '46',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '22:56.5',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:31:30Z',
#    'StartInfo': '14:31:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:51.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:51.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 18,
#    'ResultOrder': 47,
#    'IRM': None,
#    'IBUId': 'BTNOR20712199001',
#    'Name': 'ROEISELAND Marte Olsbu',
#    'ShortName': 'ROEISELAND M.',
#    'Nat': 'NOR',
#    'Bib': '18',
#    'Leg': None,
#    'Rank': '47',
#    'Shootings': '2+2',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '22:56.6',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:24:00Z',
#    'StartInfo': '14:24:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:51.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:51.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 73,
#    'ResultOrder': 48,
#    'IRM': None,
#    'IBUId': 'BTPOL21811199701',
#    'Name': 'ZUK Kamila',
#    'ShortName': 'ZUK K.',
#    'Nat': 'POL',
#    'Bib': '73',
#    'Leg': None,
#    'Rank': '48',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '22:59.0',
#    'WC': '',
#    'NC': '93',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:51:30Z',
#    'StartInfo': '14:51:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:54.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:54.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 57,
#    'ResultOrder': 49,
#    'IRM': None,
#    'IBUId': 'BTCAN22305198801',
#    'Name': 'CRAWFORD Rosanna',
#    'ShortName': 'CRAWFORD R.',
#    'Nat': 'CAN',
#    'Bib': '57',
#    'Leg': None,
#    'Rank': '49',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '23:01.3',
#    'WC': '',
#    'NC': '92',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:43:30Z',
#    'StartInfo': '14:43:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:56.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:56.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 80,
#    'ResultOrder': 50,
#    'IRM': None,
#    'IBUId': 'BTSUI21905199201',
#    'Name': 'MEINEN Susanna',
#    'ShortName': 'MEINEN S.',
#    'Nat': 'SUI',
#    'Bib': '80',
#    'Leg': None,
#    'Rank': '50',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '23:03.3',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:55:00Z',
#    'StartInfo': '14:55:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+1:58.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+1:58.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 9,
#    'ResultOrder': 51,
#    'IRM': None,
#    'IBUId': 'BTLAT22706199101',
#    'Name': 'BENDIKA Baiba',
#    'ShortName': 'BENDIKA B.',
#    'Nat': 'LAT',
#    'Bib': '9',
#    'Leg': None,
#    'Rank': '51',
#    'Shootings': '2+1',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '23:06.6',
#    'WC': '',
#    'NC': '90',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:19:30Z',
#    'StartInfo': '14:19:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:01.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:01.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 77,
#    'ResultOrder': 52,
#    'IRM': None,
#    'IBUId': 'BTAUT22101199601',
#    'Name': 'SCHWAIGER Julia',
#    'ShortName': 'SCHWAIGER J.',
#    'Nat': 'AUT',
#    'Bib': '77',
#    'Leg': None,
#    'Rank': '52',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '23:08.2',
#    'WC': '',
#    'NC': '89',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:53:30Z',
#    'StartInfo': '14:53:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:03.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:03.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 51,
#    'ResultOrder': 53,
#    'IRM': None,
#    'IBUId': 'BTUKR21801198602',
#    'Name': 'SEMERENKO Vita',
#    'ShortName': 'SEMERENKO Vita',
#    'Nat': 'UKR',
#    'Bib': '51',
#    'Leg': None,
#    'Rank': '53',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '23:08.5',
#    'WC': '',
#    'NC': '88',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:40:30Z',
#    'StartInfo': '14:40:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:03.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:03.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 49,
#    'ResultOrder': 54,
#    'IRM': None,
#    'IBUId': 'BTKAZ21701199401',
#    'Name': 'KONDRATYEVA Anastassiya',
#    'ShortName': 'KONDRATYEVA A.',
#    'Nat': 'KAZ',
#    'Bib': '49',
#    'Leg': None,
#    'Rank': '54',
#    'Shootings': '0+0',
#    'ShootingTotal': '0',
#    'RunTime': None,
#    'TotalTime': '23:10.7',
#    'WC': '',
#    'NC': '87',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:39:30Z',
#    'StartInfo': '14:39:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:05.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:05.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 65,
#    'ResultOrder': 55,
#    'IRM': None,
#    'IBUId': 'BTKAZ21902199601',
#    'Name': 'BELCHENKO Yelizaveta',
#    'ShortName': 'BELCHENKO Y.',
#    'Nat': 'KAZ',
#    'Bib': '65',
#    'Leg': None,
#    'Rank': '54',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '23:10.7',
#    'WC': '',
#    'NC': '87',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:47:30Z',
#    'StartInfo': '14:47:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:05.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:05.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 67,
#    'ResultOrder': 56,
#    'IRM': None,
#    'IBUId': 'BTBUL21004199201',
#    'Name': 'STOYANOVA Desislava',
#    'ShortName': 'STOYANOVA D.',
#    'Nat': 'BUL',
#    'Bib': '67',
#    'Leg': None,
#    'Rank': '56',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '23:12.4',
#    'WC': '',
#    'NC': '85',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:48:30Z',
#    'StartInfo': '14:48:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:07.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:07.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 32,
#    'ResultOrder': 57,
#    'IRM': None,
#    'IBUId': 'BTUKR21801198601',
#    'Name': 'SEMERENKO Valentina',
#    'ShortName': 'SEMERENKO Valentina',
#    'Nat': 'UKR',
#    'Bib': '32',
#    'Leg': None,
#    'Rank': '57',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '23:14.4',
#    'WC': '',
#    'NC': '84',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:31:00Z',
#    'StartInfo': '14:31:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:09.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:09.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 34,
#    'ResultOrder': 58,
#    'IRM': None,
#    'IBUId': 'BTSVK22211199401',
#    'Name': 'FIALKOVA Ivona',
#    'ShortName': 'FIALKOVA I.',
#    'Nat': 'SVK',
#    'Bib': '34',
#    'Leg': None,
#    'Rank': '58',
#    'Shootings': '0+3',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '23:16.4',
#    'WC': '',
#    'NC': '83',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:32:00Z',
#    'StartInfo': '14:32:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:11.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:11.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 62,
#    'ResultOrder': 59,
#    'IRM': None,
#    'IBUId': 'BTFIN20911198701',
#    'Name': 'EDER Mari',
#    'ShortName': 'EDER M.',
#    'Nat': 'FIN',
#    'Bib': '62',
#    'Leg': None,
#    'Rank': '59',
#    'Shootings': '0+4',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '23:18.4',
#    'WC': '',
#    'NC': '82',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:46:00Z',
#    'StartInfo': '14:46:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:13.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:13.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 98,
#    'ResultOrder': 60,
#    'IRM': None,
#    'IBUId': 'BTGER22010198801',
#    'Name': 'HERRMANN Denise',
#    'ShortName': 'HERRMANN D.',
#    'Nat': 'GER',
#    'Bib': '98',
#    'Leg': None,
#    'Rank': '60',
#    'Shootings': '3+2',
#    'ShootingTotal': '5',
#    'RunTime': None,
#    'TotalTime': '23:18.7',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T14:04:00Z',
#    'StartInfo': '15:04:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:13.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:13.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 78,
#    'ResultOrder': 61,
#    'IRM': None,
#    'IBUId': 'BTPOL21004199501',
#    'Name': 'ZBYLUT Kinga',
#    'ShortName': 'ZBYLUT K.',
#    'Nat': 'POL',
#    'Bib': '78',
#    'Leg': None,
#    'Rank': '61',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '23:19.6',
#    'WC': '',
#    'NC': '80',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:54:00Z',
#    'StartInfo': '14:54:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:14.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:14.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 24,
#    'ResultOrder': 62,
#    'IRM': None,
#    'IBUId': 'BTCZE20301199701',
#    'Name': 'DAVIDOVA Marketa',
#    'ShortName': 'DAVIDOVA M.',
#    'Nat': 'CZE',
#    'Bib': '24',
#    'Leg': None,
#    'Rank': '62',
#    'Shootings': '1+3',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '23:20.7',
#    'WC': '',
#    'NC': '79',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:27:00Z',
#    'StartInfo': '14:27:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:15.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:15.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 60,
#    'ResultOrder': 63,
#    'IRM': None,
#    'IBUId': 'BTRUS21509198801',
#    'Name': 'ABRAMOVA Olga',
#    'ShortName': 'ABRAMOVA O.',
#    'Nat': 'UKR',
#    'Bib': '60',
#    'Leg': None,
#    'Rank': '63',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '23:26.9',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:45:00Z',
#    'StartInfo': '14:45:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:22.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:22.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 81,
#    'ResultOrder': 64,
#    'IRM': None,
#    'IBUId': 'BTEST20401199501',
#    'Name': 'TOMINGAS Tuuli',
#    'ShortName': 'TOMINGAS T.',
#    'Nat': 'EST',
#    'Bib': '81',
#    'Leg': None,
#    'Rank': '63',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '23:26.9',
#    'WC': '',
#    'NC': '78',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:55:30Z',
#    'StartInfo': '14:55:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:22.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:22.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 37,
#    'ResultOrder': 65,
#    'IRM': None,
#    'IBUId': 'BTUSA21911198701',
#    'Name': 'EGAN Clare',
#    'ShortName': 'EGAN C.',
#    'Nat': 'USA',
#    'Bib': '37',
#    'Leg': None,
#    'Rank': '65',
#    'Shootings': '2+2',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '23:27.0',
#    'WC': '',
#    'NC': '76',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:33:30Z',
#    'StartInfo': '14:33:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:22.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:22.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 85,
#    'ResultOrder': 66,
#    'IRM': None,
#    'IBUId': 'BTBLR21602199601',
#    'Name': 'SOLA Hanna',
#    'ShortName': 'SOLA H.',
#    'Nat': 'BLR',
#    'Bib': '85',
#    'Leg': None,
#    'Rank': '66',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '23:28.8',
#    'WC': '',
#    'NC': '75',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:57:30Z',
#    'StartInfo': '14:57:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:23.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:23.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 41,
#    'ResultOrder': 67,
#    'IRM': None,
#    'IBUId': 'BTRUS20506199101',
#    'Name': 'VASILEVA Margarita',
#    'ShortName': 'VASILEVA M.',
#    'Nat': 'RUS',
#    'Bib': '41',
#    'Leg': None,
#    'Rank': '67',
#    'Shootings': '3+0',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '23:33.4',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:35:30Z',
#    'StartInfo': '14:35:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:28.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:28.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 63,
#    'ResultOrder': 68,
#    'IRM': None,
#    'IBUId': 'BTSVK20204198901',
#    'Name': 'POLIAKOVA Terezia',
#    'ShortName': 'POLIAKOVA T.',
#    'Nat': 'SVK',
#    'Bib': '63',
#    'Leg': None,
#    'Rank': '68',
#    'Shootings': '1+0',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '23:39.4',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:46:30Z',
#    'StartInfo': '14:46:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:34.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:34.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 14,
#    'ResultOrder': 69,
#    'IRM': None,
#    'IBUId': 'BTUKR21401199501',
#    'Name': 'MERKUSHYNA Anastasiya',
#    'ShortName': 'MERKUSHYNA A.',
#    'Nat': 'UKR',
#    'Bib': '14',
#    'Leg': None,
#    'Rank': '69',
#    'Shootings': '4+0',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '23:42.6',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:22:00Z',
#    'StartInfo': '14:22:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:37.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:37.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 53,
#    'ResultOrder': 70,
#    'IRM': None,
#    'IBUId': 'BTRUS22803199501',
#    'Name': 'KRUCHINKINA Irina',
#    'ShortName': 'KRUCHINKINA I.',
#    'Nat': 'BLR',
#    'Bib': '53',
#    'Leg': None,
#    'Rank': '70',
#    'Shootings': '2+2',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '23:43.1',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:41:30Z',
#    'StartInfo': '14:41:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:38.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:38.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 59,
#    'ResultOrder': 71,
#    'IRM': None,
#    'IBUId': 'BTEST23101199601',
#    'Name': 'OJA Regina',
#    'ShortName': 'OJA R.',
#    'Nat': 'EST',
#    'Bib': '59',
#    'Leg': None,
#    'Rank': '71',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '23:45.4',
#    'WC': '',
#    'NC': '70',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:44:30Z',
#    'StartInfo': '14:44:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:40.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:40.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 25,
#    'ResultOrder': 72,
#    'IRM': None,
#    'IBUId': 'BTFIN21003199501',
#    'Name': 'LEHTONEN Venla',
#    'ShortName': 'LEHTONEN V.',
#    'Nat': 'FIN',
#    'Bib': '25',
#    'Leg': None,
#    'Rank': '72',
#    'Shootings': '2+1',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '23:47.6',
#    'WC': '',
#    'NC': '69',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:27:30Z',
# ...
#    'TotalTime': '23:59.0',
#    'WC': '',
#    'NC': '63',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:50:00Z',
#    'StartInfo': '14:50:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:54.1',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:54.1',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 91,
#    'ResultOrder': 79,
#    'IRM': None,
#    'IBUId': 'BTRUS20803199401',
#    'Name': 'KAISHEVA Uliana',
#    'ShortName': 'KAISHEVA U.',
#    'Nat': 'RUS',
#    'Bib': '91',
#    'Leg': None,
#    'Rank': '79',
#    'Shootings': '2+2',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '24:02.1',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T14:00:30Z',
#    'StartInfo': '15:00:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:57.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:57.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 40,
#    'ResultOrder': 80,
#    'IRM': None,
#    'IBUId': 'BTBUL20505198901',
#    'Name': 'YORDANOVA Emiliya',
#    'ShortName': 'YORDANOVA E.',
#    'Nat': 'BUL',
#    'Bib': '40',
#    'Leg': None,
#    'Rank': '80',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '24:02.5',
#    'WC': '',
#    'NC': '61',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:35:00Z',
#    'StartInfo': '14:35:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:57.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:57.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 86,
#    'ResultOrder': 81,
#    'IRM': None,
#    'IBUId': 'BTJPN22609199201',
#    'Name': 'HACHISUKA Asuka',
#    'ShortName': 'HACHISUKA A.',
#    'Nat': 'JPN',
#    'Bib': '86',
#    'Leg': None,
#    'Rank': '81',
#    'Shootings': '0+1',
#    'ShootingTotal': '1',
#    'RunTime': None,
#    'TotalTime': '24:03.1',
#    'WC': '',
#    'NC': '59',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:58:00Z',
#    'StartInfo': '14:58:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+2:58.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+2:58.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 79,
#    'ResultOrder': 82,
#    'IRM': None,
#    'IBUId': 'BTSWE23103199501',
#    'Name': 'MAGNUSSON Anna',
#    'ShortName': 'MAGNUSSON A.',
#    'Nat': 'SWE',
#    'Bib': '79',
#    'Leg': None,
#    'Rank': '82',
#    'Shootings': '1+3',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '24:07.3',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:54:30Z',
#    'StartInfo': '14:54:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:02.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:02.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 95,
#    'ResultOrder': 83,
#    'IRM': None,
#    'IBUId': 'BTAUT20301199401',
#    'Name': 'ZDOUC Dunja',
#    'ShortName': 'ZDOUC D.',
#    'Nat': 'AUT',
#    'Bib': '95',
#    'Leg': None,
#    'Rank': '83',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '24:12.7',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T14:02:30Z',
#    'StartInfo': '15:02:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:07.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:07.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 72,
#    'ResultOrder': 84,
#    'IRM': None,
#    'IBUId': 'BTCZE20102199301',
#    'Name': 'CHARVATOVA Lucie',
#    'ShortName': 'CHARVATOVA L.',
#    'Nat': 'CZE',
#    'Bib': '72',
#    'Leg': None,
#    'Rank': '84',
#    'Shootings': '2+2',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '24:24.5',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:51:00Z',
#    'StartInfo': '14:51:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:19.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:19.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 99,
#    'ResultOrder': 85,
#    'IRM': None,
#    'IBUId': 'BTPOL22502198701',
#    'Name': 'PITON Karolina',
#    'ShortName': 'PITON K.',
#    'Nat': 'POL',
#    'Bib': '99',
#    'Leg': None,
#    'Rank': '85',
#    'Shootings': '2+2',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '24:28.6',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T14:04:30Z',
#    'StartInfo': '15:04:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:23.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:23.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 71,
#    'ResultOrder': 86,
#    'IRM': None,
#    'IBUId': 'BTJPN20601198901',
#    'Name': 'TANAKA Yurie',
#    'ShortName': 'TANAKA Y.',
#    'Nat': 'JPN',
#    'Bib': '71',
#    'Leg': None,
#    'Rank': '86',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '24:29.3',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:50:30Z',
#    'StartInfo': '14:50:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:24.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:24.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 96,
#    'ResultOrder': 87,
#    'IRM': None,
#    'IBUId': 'BTCAN21009198801',
#    'Name': 'TANDY Megan',
#    'ShortName': 'TANDY M.',
#    'Nat': 'CAN',
#    'Bib': '96',
#    'Leg': None,
#    'Rank': '87',
#    'Shootings': '2+3',
#    'ShootingTotal': '5',
#    'RunTime': None,
#    'TotalTime': '24:31.8',
#    'WC': '',
#    'NC': '47',
#    'NOC': None,
#    'StartTime': '1900-01-01T14:03:00Z',
#    'StartInfo': '15:03:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:26.9',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:26.9',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 92,
#    'ResultOrder': 88,
#    'IRM': None,
#    'IBUId': 'BTCAN21607199701',
#    'Name': 'MOSER Nadia',
#    'ShortName': 'MOSER N.',
#    'Nat': 'CAN',
#    'Bib': '92',
#    'Leg': None,
#    'Rank': '88',
#    'Shootings': '2+2',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '24:39.7',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T14:01:00Z',
#    'StartInfo': '15:01:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:34.8',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:34.8',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 82,
#    'ResultOrder': 89,
#    'IRM': None,
#    'IBUId': 'BTBUL21801199801',
#    'Name': 'TODOROVA Milena',
#    'ShortName': 'TODOROVA M.',
#    'Nat': 'BUL',
#    'Bib': '82',
#    'Leg': None,
#    'Rank': '89',
#    'Shootings': '1+1',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '24:39.9',
#    'WC': '',
#    'NC': '43',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:56:00Z',
#    'StartInfo': '14:56:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:35.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:35.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 89,
#    'ResultOrder': 90,
#    'IRM': None,
#    'IBUId': 'BTFRA23107199201',
#    'Name': 'LATUILLIERE Enora',
#    'ShortName': 'LATUILLIERE E.',
#    'Nat': 'FRA',
#    'Bib': '89',
#    'Leg': None,
#    'Rank': '90',
#    'Shootings': '2+3',
#    'ShootingTotal': '5',
#    'RunTime': None,
#    'TotalTime': '24:42.9',
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:59:30Z',
#    'StartInfo': '14:59:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:38.0',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:38.0',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 66,
#    'ResultOrder': 91,
#    'IRM': None,
#    'IBUId': 'BTLTU21704198501',
#    'Name': 'KOCERGINA Natalja',
#    'ShortName': 'KOCERGINA N.',
#    'Nat': 'LTU',
#    'Bib': '66',
#    'Leg': None,
#    'Rank': '91',
#    'Shootings': '1+2',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '24:43.4',
#    'WC': '',
#    'NC': '39',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:48:00Z',
#    'StartInfo': '14:48:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:38.5',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:38.5',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 54,
#    'ResultOrder': 92,
#    'IRM': None,
#    'IBUId': 'BTLTU22503199601',
#    'Name': 'LESCINSKAITE Gabriele',
#    'ShortName': 'LESCINSKAITE G.',
#    'Nat': 'LTU',
#    'Bib': '54',
#    'Leg': None,
#    'Rank': '92',
#    'Shootings': '0+2',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '24:57.2',
#    'WC': '',
#    'NC': '37',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:42:00Z',
#    'StartInfo': '14:42:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:52.3',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:52.3',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 102,
#    'ResultOrder': 93,
#    'IRM': None,
#    'IBUId': 'BTKAZ22403199701',
#    'Name': 'AKHATOVA Lyudmila',
#    'ShortName': 'AKHATOVA L.',
#    'Nat': 'KAZ',
#    'Bib': '102',
#    'Leg': None,
#    'Rank': '93',
#    'Shootings': '2+0',
#    'ShootingTotal': '2',
#    'RunTime': None,
#    'TotalTime': '25:03.1',
#    'WC': '',
#    'NC': '35',
#    'NOC': None,
#    'StartTime': '1900-01-01T14:06:00Z',
#    'StartInfo': '15:06:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:58.2',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:58.2',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 101,
#    'ResultOrder': 94,
#    'IRM': None,
#    'IBUId': 'BTSLO21604199701',
#    'Name': 'KLEMENCIC Polona',
#    'ShortName': 'KLEMENCIC P.',
#    'Nat': 'SLO',
#    'Bib': '101',
#    'Leg': None,
#    'Rank': '94',
#    'Shootings': '2+2',
#    'ShootingTotal': '4',
#    'RunTime': None,
#    'TotalTime': '25:04.6',
#    'WC': '',
#    'NC': '33',
#    'NOC': None,
#    'StartTime': '1900-01-01T14:05:30Z',
#    'StartInfo': '15:05:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+3:59.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+3:59.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 43,
#    'ResultOrder': 95,
#    'IRM': None,
#    'IBUId': 'BTSLO21905199401',
#    'Name': 'EINFALT Lea',
#    'ShortName': 'EINFALT L.',
#    'Nat': 'SLO',
#    'Bib': '43',
#    'Leg': None,
#    'Rank': '95',
#    'Shootings': '1+4',
#    'ShootingTotal': '5',
#    'RunTime': None,
#    'TotalTime': '25:18.6',
#    'WC': '',
#    'NC': '31',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:36:30Z',
#    'StartInfo': '14:36:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+4:13.7',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+4:13.7',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 48,
#    'ResultOrder': 96,
#    'IRM': None,
#    'IBUId': 'BTCHN20511199101',
#    'Name': 'TANG Jialin',
#    'ShortName': 'TANG J.',
#    'Nat': 'CHN',
#    'Bib': '48',
#    'Leg': None,
#    'Rank': '96',
#    'Shootings': '2+4',
#    'ShootingTotal': '6',
#    'RunTime': None,
#    'TotalTime': '26:22.5',
#    'WC': '',
#    'NC': '29',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:39:00Z',
#    'StartInfo': '14:39:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+5:17.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+5:17.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 100,
#    'ResultOrder': 97,
#    'IRM': None,
#    'IBUId': 'BTLTU22502198401',
#    'Name': 'RASIMOVICIUTE Diana',
#    'ShortName': 'RASIMOVICIUTE D.',
#    'Nat': 'LTU',
#    'Bib': '100',
#    'Leg': None,
#    'Rank': '97',
#    'Shootings': '0+3',
#    'ShootingTotal': '3',
#    'RunTime': None,
#    'TotalTime': '26:52.5',
#    'WC': '',
#    'NC': '27',
#    'NOC': None,
#    'StartTime': '1900-01-01T14:05:00Z',
#    'StartInfo': '15:05:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+5:47.6',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+5:47.6',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 88,
#    'ResultOrder': 98,
#    'IRM': None,
#    'IBUId': 'BTKOR20506199601',
#    'Name': 'KO Eunjung',
#    'ShortName': 'KO E.',
#    'Nat': 'KOR',
#    'Bib': '88',
#    'Leg': None,
#    'Rank': '98',
#    'Shootings': '2+3',
#    'ShootingTotal': '5',
#    'RunTime': None,
#    'TotalTime': '27:19.3',
#    'WC': '',
#    'NC': '25',
#    'NOC': None,
#    'StartTime': '1900-01-01T13:59:00Z',
#    'StartInfo': '14:59:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': '+6:14.4',
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': '+6:14.4',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 83,
#    'ResultOrder': 10001,
#    'IRM': 'DNS',
#    'IBUId': 'BTFIN20202199701',
#    'Name': 'FELLMAN Jenny',
#    'ShortName': 'FELLMAN J.',
#    'Nat': 'FIN',
#    'Bib': '83',
#    'Leg': None,
#    'Rank': None,
#    'Shootings': None,
#    'ShootingTotal': None,
#    'RunTime': None,
#    'TotalTime': None,
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:56:30Z',
#    'StartInfo': '14:56:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': None,
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': 'DNS',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 84,
#    'ResultOrder': 10002,
#    'IRM': 'DNS',
#    'IBUId': 'BTNOR20209199201',
#    'Name': 'BRUN-LIE Thekla',
#    'ShortName': 'BRUN-LIE T.',
#    'Nat': 'NOR',
#    'Bib': '84',
#    'Leg': None,
#    'Rank': None,
#    'Shootings': None,
#    'ShootingTotal': None,
#    'RunTime': None,
#    'TotalTime': None,
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T13:57:00Z',
#    'StartInfo': '14:57:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': None,
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': 'DNS',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 90,
#    'ResultOrder': 10003,
#    'IRM': 'DNS',
#    'IBUId': 'BTUKR22801199501',
#    'Name': 'NICIPORENKO Anastasia',
#    'ShortName': 'NICIPORENKO A.',
#    'Nat': 'MDA',
#    'Bib': '90',
#    'Leg': None,
#    'Rank': None,
#    'Shootings': None,
#    'ShootingTotal': None,
#    'RunTime': None,
#    'TotalTime': None,
#    'WC': '',
#    'NC': '',
#    'NOC': None,
#    'StartTime': '1900-01-01T14:00:00Z',
#    'StartInfo': '15:00:00',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': None,
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': 'DNS',
#    'LegRank': None,
#    'TeamRankAfterLeg': None},
#   {'StartOrder': 97,
#    'ResultOrder': 10004,
#    'IRM': 'DNS',
#    'IBUId': 'BTCZE22807199401',
#    'Name': 'JISLOVA Jessica',
#    'ShortName': 'JISLOVA J.',
#    'Nat': 'CZE',
#    'Bib': '97',
#    'Leg': None,
#    'Rank': None,
#    'Shootings': None,
#    'ShootingTotal': None,
#    'RunTime': None,
#    'TotalTime': None,
#    'WC': '',
#    'NC': None,
#    'NOC': None,
#    'StartTime': '1900-01-01T14:03:30Z',
#    'StartInfo': '15:03:30',
#    'StartRow': 0,
#    'StartLane': 0,
#    'BibColor': None,
#    'Behind': None,
#    'StartGroup': None,
#    'TeamId': None,
#    'PursuitStartDistance': 0,
#    'Result': 'DNS',
#    'LegRank': None,
#    'TeamRankAfterLeg': None}]}

# %%
complete = []
race_id = results(race['RaceId'])
race_result = race_id['Results']
race_info = race_id['Competition']

for i in range(len(race_result)):
    race_results = ((race_result[i]['ShortName'], race_result[i]['ResultOrder'],race_result[i]['TotalTime'], race_result[i]['Behind'], race_result[i]['StartOrder'], race_result[i]['ShootingTotal'], race_result[i]['Shootings']))
    race_infos = race_info['ShortDescription'], race_info['DisciplineId'], race_info['StartTime']
    comb_result = race_infos + race_results
    complete.append(comb_result)

# %%
full_result = pd.DataFrame(complete)
full_result
# Out:
#                        0   1                     2                   3      4  \
# 0    Women 7.5 km Sprint  SP  2018-12-13T13:15:00Z           WIERER D.      1
# 1    Women 7.5 km Sprint  SP  2018-12-13T13:15:00Z       MAKARAINEN K.      2
# 2    Women 7.5 km Sprint  SP  2018-12-13T13:15:00Z   YURLOVA-PERCHT E.      3
# 3    Women 7.5 km Sprint  SP  2018-12-13T13:15:00Z         VITTOZZI L.      4
# 4    Women 7.5 km Sprint  SP  2018-12-13T13:15:00Z  HOJNISZ-STAREGA M.      5
# ..                   ...  ..                   ...                 ...    ...
# 97   Women 7.5 km Sprint  SP  2018-12-13T13:15:00Z               KO E.     98
# 98   Women 7.5 km Sprint  SP  2018-12-13T13:15:00Z          FELLMAN J.  10001
# 99   Women 7.5 km Sprint  SP  2018-12-13T13:15:00Z         BRUN-LIE T.  10002
# 100  Women 7.5 km Sprint  SP  2018-12-13T13:15:00Z      NICIPORENKO A.  10003
# 101  Women 7.5 km Sprint  SP  2018-12-13T13:15:00Z          JISLOVA J.  10004
#
#            5        6   7     8     9
# 0    21:04.9      0.0  56     1   0+1
# 1    21:05.5     +0.6  22     1   0+1
# 2    21:29.3    +24.4  61     0   0+0
# 3    21:30.2    +25.3  69     1   1+0
# 4    21:33.1    +28.2  31     0   0+0
# ..       ...      ...  ..   ...   ...
# 97   27:19.3  +6:14.4  88     5   2+3
# 98      None     None  83  None  None
# 99      None     None  84  None  None
# 100     None     None  90  None  None
# 101     None     None  97  None  None
#
# [102 rows x 10 columns]
